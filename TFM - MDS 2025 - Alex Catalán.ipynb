# %% [markdown]
# # <b>(TFM) TRABAJO FINAL DE MASTER EN DATA SCIENCE</b>

# %% [markdown]
# ## <b>A. PRESENTACIÓN</b>

# %% [markdown]
# * Nombre del TFM: "Anticipando el Futuro Académico: Un Modelo de Machine Learning para Predecir la Retención de Estudiantes en la Educación Superior Técnico-Profesional en Chile"
# * Nombre estudiante: Alex Rodrigo Catalán Carrasco.
# * Nombre del Programa: Máster en Data Science.
# * Nombre institución: CEUPE
# * Nombre del tutor/a: Cristina Ruiz.

# %% [markdown]
# ## <b>B. DESARROLLO DEL INFORME / PROYECTO</b>

# %% [markdown]
# ### <b>GLOSARIO</b>

# %% [markdown]
# * **TFM**: Trabajo Fin de Master.
# * **IES**: Las siglas corresponden a Instituciones de Educación Superior.
# * **IP**: Las siglas corresponden a Instituto Profesional y son instituciones de educación superior técnico-profesional que ofrece títulos profesionales y técnicos de nivel superior, no otorga grados académicos, en donde las carreras profesionales duran en general 4 años y las técnicas entre 2 y 3 años. En Chile, los IP son entidades privadas.
# * **CFT**: Las siglas corresponden a Centro de Formación Técnica, que son instituciones de educación superior que imparten carreras técnicas. En Chile, los CFT son entidades privadas y estatales. Deben estar inscritos en el Registro Nacional de Organismos Técnicos de Capacitación. Entregan títulos de técnico de nivel superior. No otorgan grados académicos. Sus carreras tienen una duración máxima de seis semestres y el único requisito académico para que las personas puedan ingresar a un CFT es tener la licencia de enseñanza media.
# * **Retención**: La retención de estudiantes de educación superior técnico profesional en Chile es un indicador que mide la tasa de estudiantes que continúan sus estudios en el año siguiente.
# * **Tasa de Retención**: La tasa de retención es un indicador importante para evaluar la eficiencia de las instituciones de educación superior. La mayor deserción de estudiantes se produce en el primer año. Para calcular la tasa de retención se divide el número de estudiantes que se mantienen en la institución al año siguiente entre el número de estudiantes que ingresaron en primer año. Se calcula para cada cohorte de estudiantes.
# * **Cohorte**: Una cohorte de estudiantes es un grupo de alumnos que comparten una característica en común, como el año de ingreso o egreso. Los estudiantes de una misma cohorte suelen tener experiencias académicas similares. Las cohortes pueden ser útiles para: matricular a los estudiantes en un curso de manera fácil, gestionar la matriculación de estudiantes, captar y retener estudiantes, seguir la graduación de los estudiantes, brindar asesoramiento académico, entre otros.
# * **MINEDUC**: Ministerio de Educación de Chile.
# * **SIES**: Servicio de Información de Educación Superior del MINEDUC.
# * **CNA**: Comisión Nacional de Acreditación de Chile.
# * **CNED**: Consejo Nacional de Educación de Chile.
# * **JCE**: Las siglas corresponden a Jornada Completa Equivalente que representa a una unidad de comparación de la dedicación horaria del personal académico, que se obtiene al dividir el número total de horas semanales por las que están contratados los académicos en una institución de Educación Superior, por 44, donde esta última cifra corresponde o se asimila a una jornada de trabajo completa normal.

# %% [markdown]
# * ℹ️ **Información**: Este símbolo indica que se desplegará información sobre la siguiente celda de código.
# * ⚠️ **Atención**: Este símbolo indica que se debe prestar atención en el siguiente fragmento de código.
# * ⚡ **Función**: Este símbolo indica que se desplegará el código de una función en Python.
# * 📞 **LLamada a función**: Este símbolo indica que se realizará una llamada a una función creada.
# * 🖨️ **Exportación**: Este símbolo indica que se realizará la exportación de un conjunto de datos.

# %% [markdown]
# ### <b>1. INTRODUCCIÓN</b>

# %% [markdown]
# La **retención estudiantil** en las Instituciones de Educación Superior Técnico Profesional en Chile (**IP** y **CFT**) es un desafío crítico que impacta la **calidad educativa**, la **eficiencia institucional** y la **equidad en el acceso a la educación**. La tasa de retención, que mide la continuidad de los estudiantes en su trayectoria académica, varía significativamente según factores individuales, académicos, económicos e institucionales. A pesar de los esfuerzos por mejorar la permanencia estudiantil, los niveles de deserción siguen siendo elevados, afectando tanto a las instituciones como a la empleabilidad futura de los estudiantes.

# %% [markdown]
# Según datos del Servicio de Información de Educación Superior (SIES) y la Comisión Nacional de Acreditación (CNA), las tasas de retención en los IP y CFT muestran desafíos persistentes, con niveles de abandono que superan el 30% en algunos programas durante el primer año. Entre las principales causas identificadas se encuentran:
# *	**Factores individuales**: Falta de motivación, baja autoconfianza y dificultades en la adaptación al entorno educativo.
# *	**Factores académicos**: Deficiencias en formación previa, métodos de enseñanza poco efectivos y cargas académicas excesivas.
# *	**Factores económicos**: Falta de financiamiento, dificultades para compatibilizar estudios y trabajo.
# *	**Factores institucionales**: Carencia de programas de apoyo, infraestructura deficiente y escasa personalización en el seguimiento del estudiante.
# *	**Factores socioculturales**: Falta de redes de apoyo, diferencias en expectativas y nivel socioeconómico.
#
# Dado este panorama, surge la necesidad de contar con herramientas avanzadas que permitan **anticipar el riesgo de abandono estudiantil** para que las instituciones puedan implementar **estrategias de retención efectivas**.

# %% [markdown]
# ### <b>2. OBJETIVOS</b>

# %% [markdown]
# #### <b>2.1 OBJETIVO GENERAL.</b>

# %% [markdown]
# Desarrollar un modelo de Machine Learning que prediga con alta precisión la retención de estudiantes en IP y CFT en Chile, utilizando técnicas de análisis predictivo para identificar patrones de deserción y proporcionar información clave para la toma de decisiones estratégicas.

# %% [markdown]
# #### <b>2.2 OBJETIVOS ESPECÍFICOS</b>

# %% [markdown]
# * Implementar Jupyter Lab, en Ubuntu Linux, como un entorno de desarrollo integrado (IDE) del proyecto en un entorno virtual de Python.
# * Crear una *pipeline* de datos para realizar procesos ETL provenientes de diversos orígenes de datos y genere un dataset normalizado.
# * Realizar un análisis exploratorio de datos (EDA).
# * Diseñar visualizaciones de datos con Seaborn y Power BI.
# * Elaborar algoritmos de *Machine Learning* para definir el modelo predictivo.

# %% [markdown]
# #### <b>3.1 ORIGEN DE LOS DATOS</b>

# %% [markdown]
# Los conjuntos de datos se han obtenido desde las bases de datos transaccionales de una institución de educación superior en Chile mediante consultas SQL. El resultado de estas *querys*

# %% [markdown]
# #### <b>3.2 PROCESAMIENTO</b>

# %% [markdown]
# ##### <b>3.2.1 Tecnologías por utilizar</b>

# %% [markdown]
# #### <b>3.3 PROCESO ANALÍTICO</b>

# %% [markdown]
# ##### <b>3.3.1 Entorno y Librerías.</b>

# %% [markdown]
# ###### <h5>a) Entorno.</h5>

# %% [markdown]
# Creación de un entorno dedicado jupyter_env en un computador con Ubuntu. (indicar las versiones)

# %% [markdown]
# ###### <h5>b) Librerías.</h5>

# %%
# Instalación de librerías/paquetes
# %pip install openpyxl
# %pip install pandas
# %pip install numpy
# %pip install seaborn
# %pip install matplotlib
# %pip install scikit-learn
# %pip install xgboost
# Out:
# ...
#
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importación de librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ##### <b>3.3.2 Importación de los Datos.</b>

# %% [markdown]
# En esta etapa se elaboró un ___pipeline___ de datos __ETL__ con 3 alternativas de orígenes de datos:
# * Alternativa 1: Desde un repositorio personal de dataset en la nube de Google Drive. (Necesita credenciales de acceso y autenticación)
# * Alternativa 2: Desde un repositorio local de dataset en un computador con el Sistema Operativo Linux con la distribución Ubuntu 24.04.2 LTS.
# * Alternativa 3: Desde un repositorio repositorio de GitHub. (Necesita credenciales de acceso y autenticación)
# <br><br>
#
# Estas alternativas de orígenes de datos permiten al Científico de Datos:
# * Acceder a los __conjuntos de datos__ tanto ___off-line___ y ___on-line___, que luego se sincronizan al recuperar conexión a Internet.
# * Utilizar diversos ___workspaces___ y entornos de desarrollo (IDE), como __JupyterLab__, __Visual Studio Code__, __Google Colab__, entre otros.
# * Usar distintos __sistemas operativos__ para la ejecución de los ___script___ con los algoritmos escritos en __Python__, como __Linux Ubuntu__, __Microsoft Windows__, entre otros.
# * Implementar diversos __entornos virtuales de Python__ con la instalación, importación y configuración de una serie de librerías y paquetes estándares necesarios para el desarrollo del proyecto.

# %% [markdown]
# ###### <h5>a) Procesos ETL: Extracción de datos.</h5>

# %% [markdown]
# ℹ️ Definición de rutas relativas para cada archivo que contenga conjuntos de datos originales.

# %%
"""
# Alternativa 1: Importación de dataset desde Google Drive. Sólo accesible con las credenciales autorizadas.

from google.colab import drive
drive.mount('/content/drive')

# xlsx -> 1. Bases de Información de Carreras (CFT e IP) SIES del 2017 al 2025
path_xlsx_base_carreras_cftip_sies_2017_2025 = r'/content/drive/MyDrive/Colab Notebooks/DATASETS/MDS_2024_TFM/SIES/BASES_CARERRAS/Base_Carreras_IP_CFT_2017_2025_SIES.xlsx'

# xlsx -> 2. Bases de Información de Empleabilidad e Ingresos (CFT e IP) SIES del 2017 al 2025
path_xlsx_base_empleabilidad_cftip_sies_2017_2025 = r'/content/drive/MyDrive/Colab Notebooks/DATASETS/MDS_2024_TFM/SIES/BASES_EMPLEABILIDAD_E_INGRESOS/Base_Empleabilidad_e_Ingresos_2017_2025_SIES.xlsx'

# xlsx -> 3. Bases de Estadísticas por carrera (CFT e IP) SIES del 2017 al 2025
path_xlsx_estadisticas_por_carrera_cftip_sies_2017_2025 = r'/content/drive/MyDrive/Colab Notebooks/DATASETS/MDS_2024_TFM/SIES/BASES_ESTADISTICAS_POR_CARRERA/Base_Estadisticas_por_carrera_2017_2025_SIES.xlsx'

# xlsx -> 4. Bases de Información de Instituciones (CFT e IP) SIES del 2017 al 2025
path_xlsx_base_instituciones_cftip_sies_2017_2018 = r'/content/drive/MyDrive/Colab Notebooks/DATASETS/MDS_2024_TFM/SIES/BASES_INSTITUCIONES/Buscador_Instituciones_2017_2018_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2018_2019 = r'/content/drive/MyDrive/Colab Notebooks/DATASETS/MDS_2024_TFM/SIES/BASES_INSTITUCIONES/Buscador_Instituciones_2018_2019_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2019_2020 = r'/content/drive/MyDrive/Colab Notebooks/DATASETS/MDS_2024_TFM/SIES/BASES_INSTITUCIONES/Buscador_Instituciones_2019_2020_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2020_2021 = r'/content/drive/MyDrive/Colab Notebooks/DATASETS/MDS_2024_TFM/SIES/BASES_INSTITUCIONES/Buscador_Instituciones_2020_2021_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2021_2022 = r'/content/drive/MyDrive/Colab Notebooks/DATASETS/MDS_2024_TFM/SIES/BASES_INSTITUCIONES/Buscador_Instituciones_2021_2022_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2022_2023 = r'/content/drive/MyDrive/Colab Notebooks/DATASETS/MDS_2024_TFM/SIES/BASES_INSTITUCIONES/Buscador_Instituciones_2022_2023_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2023_2024 = r'/content/drive/MyDrive/Colab Notebooks/DATASETS/MDS_2024_TFM/SIES/BASES_INSTITUCIONES/Buscador_Instituciones_2023_2024_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2024_2025 = r'/content/drive/MyDrive/Colab Notebooks/DATASETS/MDS_2024_TFM/SIES/BASES_INSTITUCIONES/Buscador_Instituciones_2024_2025_SIES.xlsx'

# xlsx -> 5. Bases de Información del Personal Académico (CFT e IP) SIES del 2017 al 2024
path_xlsx_base_pac_cftip_sies_2017_2024 = r'/content/drive/MyDrive/Colab Notebooks/DATASETS/MDS_2024_TFM/SIES/BASES_PERSONAL_ACADEMICO/PAC_web_2008_2024_SIES.xlsx'
"""
# Out:
# "\n# Alternativa 1: Importación de dataset desde Google Drive. Sólo accesible con las credenciales autorizadas.\n\nfrom google.colab import drive\ndrive.mount('/content/drive')\n\n# xlsx -> 1. Bases de Información de Carreras (CFT e IP) SIES del 2017 al 2025\npath_xlsx_base_carreras_cftip_sies_2017_2025 = r'/content/drive/MyDrive/Colab Notebooks/DATASETS/MDS_2024_TFM/SIES/BASES_CARERRAS/Base_Carreras_IP_CFT_2017_2025_SIES.xlsx'\n\n# xlsx -> 2. Bases de Información de Empleabilidad e Ingresos (CFT e IP) SIES del 2017 al 2025\npath_xlsx_base_empleabilidad_cftip_sies_2017_2025 = r'/content/drive/MyDrive/Colab Notebooks/DATASETS/MDS_2024_TFM/SIES/BASES_EMPLEABILIDAD_E_INGRESOS/Base_Empleabilidad_e_Ingresos_2017_2025_SIES.xlsx'\n\n# xlsx -> 3. Bases de Estadísticas por carrera (CFT e IP) SIES del 2017 al 2025\npath_xlsx_estadisticas_por_carrera_cftip_sies_2017_2025 = r'/content/drive/MyDrive/Colab Notebooks/DATASETS/MDS_2024_TFM/SIES/BASES_ESTADISTICAS_POR_CARRERA/Base_Estadisticas_por_ca
# ...

# %%
"""
# Alternativa 2: Rutas de los orígenes de datos desde clonación de Google Drive en Local Ubuntu

# xlsx -> 1. Bases de Información de Carreras (CFT e IP) SIES del 2017 al 2025
path_xlsx_base_carreras_cftip_sies_2017_2025 = r'DATASETS/MDS_2024_TFM/SIES/BASES_CARERRAS/Base_Carreras_IP_CFT_2017_2025_SIES.xlsx'

# xlsx -> 2. Bases de Información de Empleabilidad e Ingresos (CFT e IP) SIES del 2017 al 2025
path_xlsx_base_empleabilidad_cftip_sies_2017_2025 = r'DATASETS/MDS_2024_TFM/SIES/BASES_EMPLEABILIDAD_E_INGRESOS/Base_Empleabilidad_e_Ingresos_2017_2025_SIES.xlsx'

# xlsx -> 3. Bases de Estadísticas por carrera (CFT e IP) SIES del 2017 al 2025
path_xlsx_estadisticas_por_carrera_cftip_sies_2017_2025 = r'DATASETS/MDS_2024_TFM/SIES/BASES_ESTADISTICAS_POR_CARRERA/Base_Estadisticas_por_carrera_2017_2025_SIES.xlsx'

# xlsx -> 4. Bases de Información de Instituciones (CFT e IP) SIES del 2017 al 2025
path_xlsx_base_instituciones_cftip_sies_2017_2018 = r'DATASETS/MDS_2024_TFM/SIES/BASES_INSTITUCIONES/Buscador_Instituciones_2017_2018_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2018_2019 = r'DATASETS/MDS_2024_TFM/SIES/BASES_INSTITUCIONES/Buscador_Instituciones_2018_2019_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2019_2020 = r'DATASETS/MDS_2024_TFM/SIES/BASES_INSTITUCIONES/Buscador_Instituciones_2019_2020_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2020_2021 = r'DATASETS/MDS_2024_TFM/SIES/BASES_INSTITUCIONES/Buscador_Instituciones_2020_2021_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2021_2022 = r'DATASETS/MDS_2024_TFM/SIES/BASES_INSTITUCIONES/Buscador_Instituciones_2021_2022_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2022_2023 = r'DATASETS/MDS_2024_TFM/SIES/BASES_INSTITUCIONES/Buscador_Instituciones_2022_2023_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2023_2024 = r'DATASETS/MDS_2024_TFM/SIES/BASES_INSTITUCIONES/Buscador_Instituciones_2023_2024_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2024_2025 = r'DATASETS/MDS_2024_TFM/SIES/BASES_INSTITUCIONES/Buscador_Instituciones_2024_2025_SIES.xlsx'

# xlsx -> 5. Bases de Información del Personal Académico (CFT e IP) SIES del 2017 al 2024
path_xlsx_base_pac_cftip_sies_2017_2024 = r'DATASETS/MDS_2024_TFM/SIES/BASES_PERSONAL_ACADEMICO/PAC_web_2008_2024_SIES.xlsx'
"""
# Out:
# "\n# Alternativa 2: Rutas de los orígenes de datos desde clonación de Google Drive en Local Ubuntu\n\n# xlsx -> 1. Bases de Información de Carreras (CFT e IP) SIES del 2017 al 2025\npath_xlsx_base_carreras_cftip_sies_2017_2025 = r'DATASETS/MDS_2024_TFM/SIES/BASES_CARERRAS/Base_Carreras_IP_CFT_2017_2025_SIES.xlsx'\n\n# xlsx -> 2. Bases de Información de Empleabilidad e Ingresos (CFT e IP) SIES del 2017 al 2025\npath_xlsx_base_empleabilidad_cftip_sies_2017_2025 = r'DATASETS/MDS_2024_TFM/SIES/BASES_EMPLEABILIDAD_E_INGRESOS/Base_Empleabilidad_e_Ingresos_2017_2025_SIES.xlsx'\n\n# xlsx -> 3. Bases de Estadísticas por carrera (CFT e IP) SIES del 2017 al 2025\npath_xlsx_estadisticas_por_carrera_cftip_sies_2017_2025 = r'DATASETS/MDS_2024_TFM/SIES/BASES_ESTADISTICAS_POR_CARRERA/Base_Estadisticas_por_carrera_2017_2025_SIES.xlsx'\n\n# xlsx -> 4. Bases de Información de Instituciones (CFT e IP) SIES del 2017 al 2025\npath_xlsx_base_instituciones_cftip_sies_2017_2018 = r'DATASETS/MDS_2024_TFM/SIES
# ...

# %%
# Alternativa 3: Rutas de los orígenes de datos desde clonación de Repositorio en GitHub

# xlsx -> 1. Bases de Información de Carreras (CFT e IP) SIES del 2017 al 2025
path_xlsx_base_carreras_cftip_sies_2017_2025 = r'Base_Carreras_IP_CFT_2017_2025_SIES.xlsx'

# xlsx -> 2. Bases de Información de Empleabilidad e Ingresos (CFT e IP) SIES del 2017 al 2025
path_xlsx_base_empleabilidad_cftip_sies_2017_2025 = r'Base_Empleabilidad_e_Ingresos_2017_2025_SIES.xlsx'

# xlsx -> 3. Bases de Estadísticas por carrera (CFT e IP) SIES del 2017 al 2025
path_xlsx_estadisticas_por_carrera_cftip_sies_2017_2025 = r'Base_Estadisticas_por_carrera_2017_2025_SIES.xlsx'

# xlsx -> 4. Bases de Información de Instituciones (CFT e IP) SIES del 2017 al 2025
path_xlsx_base_instituciones_cftip_sies_2017_2018 = r'Buscador_Instituciones_2017_2018_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2018_2019 = r'Buscador_Instituciones_2018_2019_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2019_2020 = r'Buscador_Instituciones_2019_2020_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2020_2021 = r'Buscador_Instituciones_2020_2021_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2021_2022 = r'Buscador_Instituciones_2021_2022_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2022_2023 = r'Buscador_Instituciones_2022_2023_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2023_2024 = r'Buscador_Instituciones_2023_2024_SIES.xlsx'
path_xlsx_base_instituciones_cftip_sies_2024_2025 = r'Buscador_Instituciones_2024_2025_SIES.xlsx'

# xlsx -> 5. Bases de Información del Personal Académico (CFT e IP) SIES del 2017 al 2024
path_xlsx_base_pac_cftip_sies_2017_2024 = r'PAC_web_2008_2024_SIES.xlsx'

# %% [markdown]
# ℹ️ Declaración y carga de los dataframes que contendrán los registros provenientes desde los conjuntos de datos originales para su posterior tratamiento (pre procesamiento).

# %%
# 1. Dataframe con los registros de todas las carreras de los (CFT e IP)) del 2017 al 2025
df_info_carreras_ipcft_sies_2017_2025 = pd.read_excel(path_xlsx_base_carreras_cftip_sies_2017_2025, sheet_name='Carreras  2017-2025')

# 2. Dataframe con los registros de información de Empleabilidad e Ingresos de las carreras de los (CFT e IP)) del 2017 al 2025
df_info_empleabilidad_ipcft_sies_2017_2025 = pd.read_excel(path_xlsx_base_empleabilidad_cftip_sies_2017_2025, sheet_name='Carreras 2017-2025')

# 3. Dataframes con los registros de la Información de Estadísticas por carrera (CFT e IP) 2017 - 2025 (SIES)
df_t_ipbm = pd.read_excel(path_xlsx_estadisticas_por_carrera_cftip_sies_2017_2025, sheet_name='t_ipbm')
df_t_tipbm = pd.read_excel(path_xlsx_estadisticas_por_carrera_cftip_sies_2017_2025, sheet_name='t_tipbm')
df_t_evol_ing = pd.read_excel(path_xlsx_estadisticas_por_carrera_cftip_sies_2017_2025, sheet_name='t_evol_ing')
df_t_emp = pd.read_excel(path_xlsx_estadisticas_por_carrera_cftip_sies_2017_2025, sheet_name='t_emp')
df_t_evol_emp = pd.read_excel(path_xlsx_estadisticas_por_carrera_cftip_sies_2017_2025, sheet_name='t_evol_emp')
df_t_tit = pd.read_excel(path_xlsx_estadisticas_por_carrera_cftip_sies_2017_2025, sheet_name='t_tit')
df_t_dur = pd.read_excel(path_xlsx_estadisticas_por_carrera_cftip_sies_2017_2025, sheet_name='t_dur')
df_t_mat = pd.read_excel(path_xlsx_estadisticas_por_carrera_cftip_sies_2017_2025, sheet_name='t_mat')
df_t_ret = pd.read_excel(path_xlsx_estadisticas_por_carrera_cftip_sies_2017_2025, sheet_name='t_ret')
df_t_dist = pd.read_excel(path_xlsx_estadisticas_por_carrera_cftip_sies_2017_2025, sheet_name='t_dist')

# 4. Dataframes con los registros de la Información de las Instituciones (CFT e IP) 2017 - 2025 (SIES)
df_instituciones_sies_2017_2018 = pd.read_excel(path_xlsx_base_instituciones_cftip_sies_2017_2018, sheet_name='Base Buscador Instituciones')
df_instituciones_sies_2018_2019 = pd.read_excel(path_xlsx_base_instituciones_cftip_sies_2018_2019, sheet_name='Buscador Instituciones 2018-19')
df_instituciones_sies_2019_2020 = pd.read_excel(path_xlsx_base_instituciones_cftip_sies_2019_2020, sheet_name='Buscador Instituciones 2020')
df_instituciones_sies_2020_2021 = pd.read_excel(path_xlsx_base_instituciones_cftip_sies_2020_2021, sheet_name='Buscador de Instituciones 2021')
df_instituciones_sies_2021_2022 = pd.read_excel(path_xlsx_base_instituciones_cftip_sies_2021_2022, sheet_name='Buscador de Instituciones 2002 ')
df_instituciones_sies_2022_2023 = pd.read_excel(path_xlsx_base_instituciones_cftip_sies_2022_2023, sheet_name='Buscador Instituciones 2023')
df_instituciones_sies_2023_2024 = pd.read_excel(path_xlsx_base_instituciones_cftip_sies_2023_2024, sheet_name='Buscador Instituciones 23-24')
df_instituciones_sies_2024_2025 = pd.read_excel(path_xlsx_base_instituciones_cftip_sies_2024_2025, sheet_name='Buscador Instituciones')

# 5. Dataframes con los registros del Personal Académico (CFT e IP) 2017 - 2024 (SIES)
df_pac_num_sies_2017_2024 = pd.read_excel(path_xlsx_base_pac_cftip_sies_2017_2024, sheet_name='BD_Acádemicos_Número')
df_pac_jce_sies_2017_2024 = pd.read_excel(path_xlsx_base_pac_cftip_sies_2017_2024, sheet_name='BD_Académicos_JCE')

# %% [markdown]
# ℹ️ Listado de los dataframes creados imprimiendo su dimensión para validación.

# %%
# Dimesión de los dataframes.
print('A: Dataframes de Base de Carreras CFT e IP del 2017 al 2025.')
print(f'-> 1. [df_info_carreras_ipcft_sies_2017_2025]: {df_info_carreras_ipcft_sies_2017_2025.shape}\n\n')

print('B: Dataframes de Información de Empleabilidad e Ingresos CFT e IP del 2017 al 2025.')
print(f'-> 1. [df_info_empleabilidad_ipcft_sies_2017_2025]: {df_info_empleabilidad_ipcft_sies_2017_2025.shape}\n\n')

print('C: Dataframes de Estadísticas por Carrera CFT e IP del 2017 al 2025.')
print(f'-> 1. Ingreso promedio bruto mensual [df_t_ipbm]: {df_t_ipbm.shape}')
print(f'-> 2. Tramos de ingreso promedio bruto mensual [df_t_tipbm]: {df_t_tipbm.shape}')
print(f'-> 3. Evolución de los ingresos [df_t_evol_ing]: {df_t_evol_ing.shape}')
print(f'-> 4. Empleabilidad [df_t_emp]: {df_t_emp.shape}')
print(f'-> 5. Evolución de la Empleabilidad [df_t_evol_emp]: {df_t_evol_emp.shape}')
print(f'-> 6. Titulaciones [df_t_tit]: {df_t_tit.shape}')
print(f'-> 7. Duración de carreras [df_t_dur]: {df_t_dur.shape}')
print(f'-> 8. Matrículas [df_t_mat]: {df_t_mat.shape}')
print(f'-> 8. Retención [df_t_ret]: {df_t_ret.shape}')
print(f'-> 9. Distribución [df_t_dist]: {df_t_dist.shape}\n\n')

print('D: Dataframes de Información de Instituciones CFT e IP del 2017 al 2025.')
print(f'-> 1. Periodo 2017-2018 [df_instituciones_sies_2017_2018]: {df_instituciones_sies_2017_2018.shape}')
print(f'-> 2. Periodo 2018-2019 [df_instituciones_sies_2018_2019]: {df_instituciones_sies_2018_2019.shape}')
print(f'-> 3. Periodo 2019-2020 [df_instituciones_sies_2019_2020]: {df_instituciones_sies_2019_2020.shape}')
print(f'-> 4. Periodo 2020-2021 [df_instituciones_sies_2020_2021]: {df_instituciones_sies_2020_2021.shape}')
print(f'-> 5. Periodo 2021-2022 [df_instituciones_sies_2021-2022]: {df_instituciones_sies_2021_2022.shape}')
print(f'-> 6. Periodo 2022-2023 [df_instituciones_sies_2022-2023]: {df_instituciones_sies_2022_2023.shape}')
print(f'-> 7. Periodo 2023-2024 [df_instituciones_sies_2023-2024]: {df_instituciones_sies_2023_2024.shape}')
print(f'-> 8. Periodo 2024-2025 [df_instituciones_sies_2024-2025]: {df_instituciones_sies_2024_2025.shape}\n\n')

print('E: Dataframes de Información del Personal Académico CFT e IP del 2017 al 2024.')
print(f'-> 1. Número del Personal Académico [df_pac_num_sies_2017_2024]: {df_pac_num_sies_2017_2024.shape}')
print(f'-> 2. JCE del Personal Académico [df_jce_num_sies_2017_2024]: {df_pac_jce_sies_2017_2024.shape}')
# Out:
# A: Dataframes de Base de Carreras CFT e IP del 2017 al 2025.
# -> 1. [df_info_carreras_ipcft_sies_2017_2025]: (56037, 40)
#
#
# B: Dataframes de Información de Empleabilidad e Ingresos CFT e IP del 2017 al 2025.
# -> 1. [df_info_empleabilidad_ipcft_sies_2017_2025]: (4165, 15)
#
#
# C: Dataframes de Estadísticas por Carrera CFT e IP del 2017 al 2025.
# -> 1. Ingreso promedio bruto mensual [df_t_ipbm]: (1078, 11)
# -> 2. Tramos de ingreso promedio bruto mensual [df_t_tipbm]: (2156, 12)
# -> 3. Evolución de los ingresos [df_t_evol_ing]: (5390, 9)
# -> 4. Empleabilidad [df_t_emp]: (2156, 7)
# -> 5. Evolución de la Empleabilidad [df_t_evol_emp]: (6982, 9)
# -> 6. Titulaciones [df_t_tit]: (1078, 9)
# -> 7. Duración de carreras [df_t_dur]: (1078, 8)
# -> 8. Matrículas [df_t_mat]: (1190, 12)
# -> 8. Retención [df_t_ret]: (1078, 8)
# -> 9. Distribución [df_t_dist]: (1190, 10)
#
#
# D: Dataframes de Información de Instituciones CFT e IP del 2017 al 2025.
# ...

# %% [markdown]
# ℹ️ Muestreo de los registros de los dataframes creados.

# %%
# Muestra de los datos de los dataframes.

# df_info_carreras_ipcft_sies_2017_2025.head(3)

# df_info_empleabilidad_ipcft_sies_2017_2025.head(3)

# df_t_ipbm.head(3)
# df_t_tipbm.head(3)
# df_t_evol_ing.head(3)
# df_t_emp.head(3)
# df_t_evol_emp.head(3)
# df_t_dur.head(3)
# df_t_mat.head(3)
df_t_ret.head(3)
# df_t_tit.head(3)
# df_t_dist.head(3)

# df_instituciones_sies_2017_2018.head(3)
# df_instituciones_sies_2018_2019
# df_instituciones_sies_2019_2020
# df_instituciones_sies_2020_2021
# df_instituciones_sies_2021_2022
# df_instituciones_sies_2022_2023
# df_instituciones_sies_2023_2024
# df_instituciones_sies_2024_2025.head(3)

# df_pac_num_sies_2017_2024
# df_pac_jce_sies_2017_2024.head(3)
# Out:
#   Periodo SIES  ID Carrera               Área Carrera  \
# 0    2024-2025           1  Administración y Comercio
# 1    2024-2025           3               Agropecuaria
# 2    2024-2025           4                  Educación
#
#             Tipo de institución                            Carrera genérica  \
# 0  Centros de Formación Técnica                       Secretariado Bilingüe
# 1  Centros de Formación Técnica                        Técnico Agropecuario
# 2  Centros de Formación Técnica  Técnico Asistente del Educador de Párvulos
#
#    Cohorte   1er año 2do año
# 0     2022  0.742857     s/i
# 1     2022  0.698506     s/i
# 2     2022  0.762731     s/i

# %% [markdown]
# ###### <h5>b) Procesos ETL: Transformación de las estructuras de datos.</h5>

# %% [markdown]
# <blockquote>Las transformaciones que se realizaron durante el <i>pipeline</i> de datos ETL consideró la creación de dataframes que incluyeron la información general y descriptiva de las instituciones de educación superior de tipo CFT e IP según la estructura de datos de SIES. Estos dataframes se presentarán como un homologable de tablas SQL.</blockquote>

# %% [markdown]
# <u>Primero</u>: Definición de <b>columnas de los dataframes</b>. ✔️
# <ul>
#     <li>Estas columnas han sido homologadas para los distintos <i>dataset</i> correspondientes a los periodos SIES.</li>
#     <li>Por convención de buenas prácticas en Python, se definirán los nombres de columnas del dataframe de forma descriptiva y legible de acuerdo con:</li>
#     <ul>
#         <li>uso de minúsculas,</li>
#         <li>Snake Case (separar las palabras con guiones bajos),</li>
#         <li>sin espacios,</li>
#         <li>sin tildes,</li>
#         <li>ni caracteres especiales.</li>
#     </ul>
# </ul>

# %%
# Lista [cols_t_info_gral_cft_ip_sies] con los nombres de las columnas del dataframe [t_info_gral_cft_ip_sies].
cols_t_info_gral_cft_ip_sies = [
    "cod_ies",  # Código identificador SIES de la IES.
    "tipo_inst",  # Tipo de institución 1: Centros de Formación Técnica e Institutos Profesionales.
    "nombre_inst",  # Nombre de la institución.
    "dir_sede_central",  # Dirección de la sede central de la institución.
    "pag_web",  # Sito Web de la institución.
]

# Lista [cols_t_info_sii_cft_ip_sies] con los nombres de las columnas del dataframe [t_info_sii_cft_ip_sies].
cols_t_info_sii_cft_ip_sies = [
    "cod_ies",  # Código identificador SIES de la IES.
    "tipo_inst",  # Tipo de institución 1: Centros de Formación Técnica e Institutos Profesionales.
    "rut_ies",  # Rol Único Tributario de la IES.
    "tipo_soc",  # Tipo de sociedad de la IES.
]

# Lista [cols_t_info_acred_cft_ip_sies] con los nombres de las columnas del dataframe [t_info_acred_cft_ip_sies].
cols_t_info_acred_cft_ip_sies = [
    "per_sies",  # Perido SIES.
    "cod_ies",  # Código identificador SIES de la IES.
    "tipo_inst",  # Tipo de institución 1: Centros de Formación Técnica e Institutos Profesionales.
    "situa_auton",  # Situación de autonomía de la IES.
    "situa_acred",  # Situación de acreditación de la IES.
    "anios_acred",  # Años de acreditación de la IES.
    "perio_acred",  # Periodo de acreditación de la IES.
    "areas_oblig_acred",  # Áreas de acreditación obligatorias de las IES.
    "areas_elect_acred",  # Áreas electivas de acreditación de las IES.
]

# Lista [cols_t_pac_num_sies] con los nombres de las columnas del dataframe [t_pac_num_sies].
cols_t_pac_num_sies = [
    "per_sies",  # Periodo SIES
    "cod_ies",  # Código Institución SIES
    "tipo_inst",  # Tipo de institución SIES (Luego se elimina)
    "total_mujeres",  # Total de mujeres académicas
    "total_hombres",  # Total de hombres académicos
    "total_gral",  # Total de académicos
    "prom_edad_mujeres",  # Promedio de edad de mujeres
    "prom_edad_hombres",  # Promedio de edad de hombres
    "prom_edad_inst",  # Promedio de edad del total de académicos en la institución
    "num_acad_1_inst",  # Número de académicos que trabaja en 1 institución
    "num_acad_2_inst",  # Número de académicos que trabaja en 2 instituciones
    "num_acad_3_mas_inst",  # Número de académicos que trabaja en 3 o más instituciones.
    "num_acad_nform_doctor",  # Número de académicos con nivel de formación: Doctor
    "num_acad_nform_magister",  # Número de académicos con nivel de formación: Magister
    "num_acad_nform_esp_med_odo",  # Número de académicos con nivel de formación: Especialidad médido y dontológica
    "num_acad_nform_tit_prof",  # Número de académicos con nivel de formación: Título profesional
    "num_acad_nform_licencia",  # Número de académicos con nivel de formación: Licenciatura en Educación Superior
    "num_acad_nform_tns",  # Número de académicos con nivel de formación: Técnico en Nivel Superior
    "num_acad_nform_tnm",  # Número de académicos con nivel de formación: Técnico en Nivel Medio
    "num_acad_nform_ens_media",  # Número de académicos con nivel de formación: Licenciatura de Enseñanza Media
    "num_acad_nform_stit_sgra",  # Número de académicos con nivel de formación: Sin título, ni grado académico
    "num_acad_nform_sin_info",  # Número de académicos con nivel de formación: Sin información
    "num_acad_reg_ar_pa",  # Número de académicos con nivel de formación: Región de Arica y Parinacota
    "num_acad_reg_tarap",  # Número de académicos con nivel de formación: Región de Tarapacá
    "num_acad_reg_antof",  # Número de académicos con nivel de formación: Región de Antofagasta
    "num_acad_reg_ataca",  # Número de académicos con nivel de formación: Región de Atacáma
    "num_acad_reg_coqui",  # Número de académicos con nivel de formación: Región de Coquimbo
    "num_acad_reg_valpo",  # Número de académicos con nivel de formación: Región de Valparaíso
    "num_acad_reg_metro",  # Número de académicos con nivel de formación: Región Metropolitana
    "num_acad_reg_ohigg",  # Número de académicos con nivel de formación: Región de O'Higgins
    "num_acad_reg_maule",  # Número de académicos con nivel de formación: Región del Maule
    "num_acad_reg_nuble",  # Número de académicos con nivel de formación: Región del Ñuble
    "num_acad_reg_biobi",  # Número de académicos con nivel de formación: Región del Bíobío
    "num_acad_reg_arau",  # Número de académicos con nivel de formación: Región de la Araucanía
    "num_acad_reg_losri",  # Número de académicos con nivel de formación: Región de los Ríos
    "num_acad_reg_losla",  # Número de académicos con nivel de formación: Región de los Lagos
    "num_acad_reg_aysen",  # Número de académicos con nivel de formación: Región de Aysén
    "num_acad_reg_magal",  # Número de académicos con nivel de formación: Región de Magallanes y la Antártica
    "num_acad_reg_sin_inf",  # Número de académicos con nivel de formación: Sin información
    "num_acad_nac_chile",  # Número de académicos con nacionalidad: Chileno
    "num_acad_nac_extra",  # Número de académicos con nacionalidad: Extranjero
    "prom_gral_hrs_acad",  # Promedio general institucional de horas acádemicas contratadas a la semana por académico
    "prom_muj_hrs_acad",  # Promedio institucional de horas acádemicas de mujeres contratadas a la semana por académico
    "prom_hom_hrs_acad",  # Promedio institucional de horas acádemicas de hombres contratadas a la semana por académico
    "num_acad_hrs_menos_11",  # N° de académicos por rango de horas contratadas: Menos de 11
    "num_acad_hrs_ent_11_22",  # N° de académicos por rango de horas contratadas: Entre 11 y menos de 23
    "num_acad_hrs_ent_23_38",  # N° de académicos por rango de horas contratadas: Entre 23 y menos de 39
    "num_acad_hrs_mas_38",  # N° de académicos por rango de horas contratadas: Entre 39 y más
    "num_acad_hrs_sin_info",  # N° de académicos por rango de horas contratadas: Sin información
]

# Lista [cols_t_pac_jce_sies] con los nombres de las columnas del dataframe [t_pac_jce_sies].
cols_t_pac_jce_sies = [
    "per_sies",  # Periodo SIES
    "cod_ies",  # Código Institución SIES
    "tipo_inst",  # N/A para esta tabla
    "total_jce_mujeres",  # Total JCE de mujeres académicas
    "total_jce_hombres",  # Total JCE de hombres académicos
    "total_jce_gral",  # Total JCE de académicos
    "prom_edad_jce_mujeres",  # Promedio de edad ponderado de mujeres por JCE
    "prom_edad_jce_hombres",  # Promedio de edad ponderado de hombres por JCE
    "prom_edad_jce_inst",  # Promedio de edad ponderado por JCE por institución
    "num_jce_1_inst",  # Número de JCE de la institución que trabajan en 1 institución
    "num_jce_2_inst",  # Número de JCE de la institución que trabajan en 2 instituciones
    "num_jce_3_mas_inst",  # Número de JCE de la institución que trabajan en 3 o más instituciones
    "num_jce_nform_doctor",  # Número de JCE por nivel de formación: Doctor
    "num_jce_nform_magister",  # Número de JCE por nivel de formación: Magister
    "num_jce_nform_esp_med_odo",  # Número de JCE por nivel de formación: Especialidad médica y odontológica
    "num_jce_nform_tit_prof",  # Número de JCE por nivel de formación: Título Profesional
    "num_jce_nform_licen",  # Número de JCE por nivel de formación: Licenciatura de Educación Superior
    "num_jce_nform_tns",  # Número de JCE por nivel de formación: Técnico de Nivel Superior
    "num_jce_nform_tnm",  # Número de JCE por nivel de formación: Técnico de Nivel Medio
    "num_jce_nform_ens_media",  # Número de JCE por nivel de formación: Enseñanza Media
    "num_jce_nform_stit_sgra",  # Número de JCE por nivel de formación: Sin título, ni grado
    "num_jce_nform_sin_info",  # Número de JCE por nivel de formación: Sin información
    "num_jce_reg_ar_pa",  # Número de JCE por región en que se desempeña: Región de Arica y Parinacota
    "num_jce_reg_tarap",  # Número de JCE por región en que se desempeña: Región  de Tarapacá
    "num_jce_reg_antof",  # Número de JCE por región en que se desempeña: Región de Antofagasta
    "num_jce_reg_ataca",  # Número de JCE por región en que se desempeña: Región de Atacama
    "num_jce_reg_coqui",  # Número de JCE por región en que se desempeña: Región de Coquimbo
    "num_jce_reg_valpo",  # Número de JCE por región en que se desempeña: Región de Valparaíso
    "num_jce_reg_metro",  # Número de JCE por región en que se desempeña: Región Metropolitana
    "num_jce_reg_ohigg",  # Número de JCE por región en que se desempeña: Región de O'Higgins
    "num_jce_reg_maule",  # Número de JCE por región en que se desempeña: Región del Maule
    "num_jce_reg_nuble",  # Número de JCE por región en que se desempeña: Región del Ñuble
    "num_jce_reg_biobi",  # Número de JCE por región en que se desempeña: Región del Biobío
    "num_jce_reg_arau",  # Número de JCE por región en que se desempeña: Región de la Araucanía
    "num_jce_reg_losri",  # Número de JCE por región en que se desempeña: Región de los Ríos
    "num_jce_reg_losla",  # Número de JCE por región en que se desempeña: Región de los Lagos
    "num_jce_reg_aysen",  # Número de JCE por región en que se desempeña: Región de Aysén
    "num_jce_reg_magal",  # Número de JCE por región en que se desempeña: Región de Magallanes y la Artártica
    "num_jce_reg_sin_inf",  # Número de JCE por región en que se desempeña: Sin información
    "num_jce_nac_chile",  # Número de JCE por nacionalidad: Chilena
    "num_jce_nac_extra",  # Número de JCE por nacionalidad: Extranjera
    "num_jce_hrs_menos_11",  # Numero de JCE por rango de horas contratadas: Menos de 11
    "num_jce_hrs_ent_11_22",  # Numero de JCE por rango de horas contratadas: Entre 11 y menos de 23
    "num_jce_hrs_ent_23_38",  # Numero de JCE por rango de horas contratadas: Entre 23 y menos de 39
    "num_jce_hrs_mas_38",  # Numero de JCE por rango de horas contratadas: Entre 39 y más
]

# Lista [cols_t_info_carreras_cft_ip_sies] con los nombres de las columnas del dataframe [t_info_carreras_cft_ip_sies].
cols_t_info_carreras_cft_ip_sies = [
    "per_sies",  # Periodo SIES
    "cod_carr",  # Código de la carrera
    "cod_sies",  # Código Institución SIES
    "area_con",  # Área de conocimiento
    "tipo_inst",  # N/A para esta tabla
    "nom_carr",  # Nombre de la carrera
    "reg_carr",  # Región en donde se oferta la carrera
    "jor_carr",  # Jornada en donde se imparte la carrera
    "sede_carr",  # Sede en donde se oferta la carrera
    "arancel_anual_carr",  # Monto arancel anual de la carrera
    # "anio_arancel_anual_carr",  # Año del arancel anual de la carrera
    "costo_tit_carr",  # Costo del proceso de titulación de la carrera
    "dur_form_carr",  # Duración formal de la carrera (en semestres)
    "niv_carr",  # Nivel de la carrera (Profesional o Técnico de Nivel Superior)
    # "anio_mat_tot_carr",  # Año de la matrícula total en la carrera
    "mat_tot_fem_carr",  # Matrícula total femina en la carrera
    "mat_tot_mas_carr",  # Matrícula total masculina en la carrera
    "mat_tot_carr",  # Matrícula total en la carrera
    # "anio_mat_1er_anio_carr",  # Año de la matrícula de primer año en la carrera
    "mat_1er_anio_fem_carr",  # Matrícula de primer año femenina en la carrera
    "mat_1er_anio_masc_carr",  # Matrícula de primer año masculina en la carrera
    "mat_tot_1er_anio_carr",  # Matrícula total de primer año en la carrera
    "porc_mat_est_mun",  # Porcentaje de matriculados según establecimiento de origen: Municipal y Servicios Locales
    "porc_mat_est_par_sub",  # Porcentaje de matriculados según establecimiento de origen: Particular Subvencionado
    "porc_mat_est_par_pag",  # Porcentaje de matriculados según establecimiento de origen: Particular Pagado
    "porc_mat_est_adm",  # Porcentaje de matriculados según establecimiento de origen: Administración Delegada
    # "anio_tit_carr",  # Año de la titulación de la carrera
    "tit_tot_fem_carr",  # Titulados totales femeninas de la carrera
    "tit_tot_mas_carr",  # Titulados totales masculinos de la carrera
    "tit_tot_carr",  # Titulados totales de la carrera
    "prom_nem",  # Promedio de NEM para el año de la matrícula
    "vac_1er_sem_carr",  # Número de vacantes de la carrera en el primer semestre
    "area_carr_gen",  # Área carrera genérica
]

# Lista [cols_new_t_info_carreras_cft_ip_sies] con los nombres de las nuevas columnas del dataframe [t_info_carreras_cft_ip_sies].
cols_new_t_info_carreras_cft_ip_sies = [
    "anio_arancel_anual_carr",  # Año del arancel anual de la carrera
    "anio_mat_tot_carr",  # Año de la matrícula total en la carrera    
    "anio_mat_1er_anio_carr",  # Año de la matrícula de primer año en la carrera
    "anio_tit_carr",  # Año de la titulación de la carrera
]

# Lista [cols_t_info_empleabilidad_ipcft_sies_2017_2025] con los nombres de las columnas del dataframe [t_info_empleabilidad_ipcft_sies_2017_2025].
cols_t_info_empleabilidad_ipcft_sies_2017_2025 = [
    'cod_sies', # Código Institución SIES
    'acred_inst', # Estado y años de acreditación carrera
    'area_carr', # Área en donde pertene la carrera
    'nom_carr_gen', # Nombre de la carrera genérica
    'nom_carr_tit', # Nombre de la carrera del título
    'porc_tit_cont_est', # Porcentaje de titulados con continuidad de estudios
    'ret_1er_anio', # Tasa de retención de estudiantes al primera año de la carrera
    'dur_real_carr_sem', # Duración promedio real de la carrera (semestres)
    'emp_1er_anio_tit_carr', # Tasa de empleabilidad al primer año de titulación de la carrera
    'emp_2do_anio_tit_carr', # Tasa de empleabilidad al segundo año de titulación de la carrera
    'ing_prom_4to_anio_tit', # Ingreso promedio al cuarto año de titulación de la carrera
    'arancel_anual_carr', # Arancel anual de la carrera
    'per_sies', # Periodo SIES
]

# Lista [cols_t_info_empleabilidad_ipcft_sies_2017_2025] con los nombres de las columnas del dataframe [t_info_empleabilidad_ipcft_sies_2017_2025].
cols_t_info_empleabilidad_ipcft_sies_2017_2025 = [
    'cod_sies', # Código Institución SIES
    'acred_inst', # Estado y años de acreditación carrera
    'area_carr', # Área en donde pertene la carrera
    'nom_carr_gen', # Nombre de la carrera genérica
    'nom_carr_tit', # Nombre de la carrera del título
    'porc_tit_cont_est', # Porcentaje de titulados con continuidad de estudios
    'ret_1er_anio', # Tasa de retención de estudiantes al primera año de la carrera
    'dur_real_carr_sem', # Duración promedio real de la carrera (semestres)
    'emp_1er_anio_tit_carr', # Tasa de empleabilidad al primer año de titulación de la carrera
    'emp_2do_anio_tit_carr', # Tasa de empleabilidad al segundo año de titulación de la carrera
    'ing_prom_4to_anio_tit', # Ingreso promedio al cuarto año de titulación de la carrera
    'arancel_anual_carr', # Arancel anual de la carrera
    'per_sies', # Periodo SIES
]

# Lista [cols_t_dist] con los nombres de las columnas del dataframe [t_dist].
cols_t_dist = [
    'per_sies', # Periodo SIES
    'id_carr_gen', # Código identificador de la carrera genérica
    'area_carr', # Área de la carrera
    'tipo_inst', # Tipo de institución
    'nom_carr_gen', # Nombre de la carrera genérica
    'anio_mat', # Año de la matrícula
    'dist_mat_mun', # Tasa de matrícula en establecimientos de tipo municipal subvencionado
    'dist_mat_part', # Tasa de matrícula en establecimientos de tipo particular subvencionado
    'dist_mat_pag', # Tasa de matrícula en establecimientos de tipo particular pagado
    'dist_mat_adm', # Tasa de matrícula en establecimientos de tipo administración delegada
]

# Lista [cols_t_dur] con los nombres de las columnas del dataframe [t_dur].
cols_t_dur = [
    'per_sies', # Periodo SIES
    'id_carr_gen', # Código identificador de la carrera genérica
    'area_carr', # Área de la carrera
    'tipo_inst', # Tipo de institución
    'nom_carr_gen', # Nombre de la carrera genérica
    'anio_base_tit', # Año base de titulación
    'dur_formal_carr', # Duración formal de la carrera
    'dur_real_carr', # Duración real de la carrera
]

# Lista [cols_t_emp] con los nombres de las columnas del dataframe [t_emp].
cols_t_emp = [
    'per_sies', # Periodo SIES
    'id_carr_gen', # Código identificador de la carrera genérica
    'area_carr', # Área de la carrera
    'tipo_inst', # Tipo de institución
    'nom_carr_gen', # Nombre de la carrera genérica
    'per_tit_carr', # Periodo de titulación de la carrera: 1er o 2do año
    'tasa_emp', # Tasa de empleabilidad de la carrera
]

# Lista [cols_t_evol_emp] con los nombres de las columnas del dataframe [t_evol_emp].
cols_t_evol_emp = [
    'per_sies', # Periodo SIES
    'id_carr_gen', # Código identificador de la carrera genérica
    'area_carr', # Área de la carrera
    'tipo_inst', # Tipo de institución
    'nom_carr_gen', # Nombre de la carrera genérica
    'per_tit_carr', # Periodo de titulación de la carrera: 1er o 2do año
    'coho_tit', # Cohorte de titulación
    'anio_emp', # Año de empleabilidad
    'tasa_emp', # Tasa de empleabilidad de la carrera
]

# Lista [cols_t_evol_ing] con los nombres de las columnas del dataframe [t_evol_ing].
cols_t_evol_ing = [
    'per_sies', # Periodo SIES
    'id_carr_gen', # Código identificador de la carrera genérica
    'area_carr', # Área de la carrera
    'tipo_inst', # Tipo de institución
    'nom_carr_gen', # Nombre de la carrera genérica
    'fecha_act', # Fecha de actualización de las estadísticas
    'coho_tit', # Cohorte de titulación
    'per_tit_carr', # Periodo de titulación de la carrera: 1er o 5to año
    'prom_ing_4to_anio:tit', # Promedio de ingresos al cuarto año de titulación
]

# Lista [cols_t_ipbm] con los nombres de las columnas del dataframe [t_ipbm].
cols_t_ipbm = [
    'per_sies', # Periodo SIES
    'id_carr_gen', # Código identificador de la carrera genérica
    'area_carr', # Área de la carrera
    'tipo_inst', # Tipo de institución
    'nom_carr_gen', # Nombre de la carrera genérica
    'fecha_act', # Fecha de actualización de las estadísticas
    'ipbm_1er_anio', # Ingreso promedio bruto mensual al primer año de titulación de la carrera
    'ipbm_2do_anio', # Ingreso promedio bruto mensual al segundo año de titulación de la carrera
    'ipbm_3er_anio', # Ingreso promedio bruto mensual al tercer año de titulación de la carrera
    'ipbm_4to_anio', # Ingreso promedio bruto mensual al cuarto año de titulación de la carrera
    'ipbm_5to_anio', # Ingreso promedio bruto mensual al quinto año de titulación de la carrera
]

# Lista [cols_t_mat] con los nombres de las columnas del dataframe [t_mat].
cols_t_mat = [
    'per_sies', # Periodo SIES
    'id_carr_gen', # Código identificador de la carrera genérica
    'area_carr', # Área de la carrera
    'tipo_inst', # Tipo de institución
    'nom_carr_gen', # Nombre de la carrera genérica
    'anio_mat', # Año de la matrícula
    'mat_1er_anio_mujeres', # Total de matriculas de primer año mujeres
    'mat_1er_anio_hombres', # Total de matriculas de primer año hombres
    'mat_1er_anio_total', # Total de matriculas de primer año
    'mat_tot_mujeres', # Total de matriculas mujeres
    'mat_tot_hombres', # Total de matriculas hombres
    'mat_total', # Total de matricula
]

# Lista [cols_t_ret] con los nombres de las columnas del dataframe [t_ret].
cols_t_ret = [
    'per_sies', # Periodo SIES
    'id_carr_gen', # Código identificador de la carrera genérica
    'area_carr', # Área de la carrera
    'tipo_inst', # Tipo de institución
    'nom_carr_gen', # Nombre de la carrera genérica
    'coho_mat', # Cohorte de matrícula
    'tasa_ret_1er_anio', # Tasa de retención de primer año de matrícula
    'tasa_ret_2do_anio', # Tasa de retención de segundo año de matrícula
]

# Lista [cols_t_tipbm] con los nombres de las columnas del dataframe [t_tipbm].
cols_t_tipbm = [
    'per_sies', # Periodo SIES
    'id_carr_gen', # Código identificador de la carrera genérica
    'area_carr', # Área de la carrera
    'tipo_inst', # Tipo de institución
    'nom_carr_gen', # Nombre de la carrera genérica
    'fecha_act', # Fecha de actualización de las estadísticas
    'per_tit_carr', # Periodo de titulación de la carrera: 1er o 5to año
    'tra_10_inf', # Tramo del Ingreso Bruto Mensual: 10% inferior
    'tra_25_inf', # Tramo del Ingreso Bruto Mensual: 25% inferior
    'tra_50_perc', # Tramo del Ingreso Bruto Mensual: Percentil 50
    'tra_25_sup', # Tramo del Ingreso Bruto Mensual: 25% superior
    'tra_10_sup', # Tramo del Ingreso Bruto Mensual: 10% superior
]

# Lista [cols_t_tit] con los nombres de las columnas del dataframe [t_tit].
cols_t_tit = [
    'per_sies', # Periodo SIES
    'id_carr_gen', # Código identificador de la carrera genérica
    'area_carr', # Área de la carrera
    'tipo_inst', # Tipo de institución
    'nom_carr_gen', # Nombre de la carrera genérica
    'coho_tit', # Cohorte de titulación
    'tit_mujeres', # Total de titulados mujeres
    'tit_hombres', # Total de titulados hombres
    'tit_total', # Total de titulados
]

# %% [markdown]
# <u>Segundo</u>: Creación de <b>dataframes</b> finales. ✔️ <br>
# Este proceso de transformación considera e implica que:
# <ul>
#     <li>Se desagrupen los <i>dataframes</i> que contienen la <i>data</i> cruda extraída sin procesar.</li>
#     <li>Se creen <i>dataframes</i> descriptibles (estandarizables con tablas SQL) con columnas en específico que incluyan siempre un identificador de cada registro.</li>
#     <li>Se eliminen o agreguen columnas y/o filas de los <i>dataframes</i> de acuerdo a las necesidades de las reglas de negocio y el modelo relacional de datos.</li>
#     <li>Se deban verificar los registros de cada <i>dataframe</i> de acuerdo con los criterios de calidad de los datos.</li>
# </ul>

# %% [markdown]
# ℹ️ **(procesar_df_instituciones_sies)** Función que permite modularizar las operaciones relacionadas con las transformaciones y creación de los dataframes con información general de las IES (CFT e IP).

# %%
def procesar_df_instituciones_sies(tabla, df_x_per, cols):
    match tabla:
        case 't_info_gral_cft_ip_sies':
            # Extracción de las columnas
            df_temp = df_x_per.iloc[:, :6]

            # Eliminación de la columna 'Unnamed: 3' asociada a la 'Autonomía' que se incluirá en el dataframe t_info_acred_cft_ip_sies.
            df_temp = df_temp.drop(df_temp.columns[3], axis=1)

            # Renombrar las columnas del nuevo dataframe
            df_temp.columns = cols

            # ELiminar la primera fila del nuevo dataframe que contiene los nombres de las columnas 
            # (esto ocurrió por defecto al importar los datos de la planilla excel al dataframe)
            df_temp = df_temp.iloc[1:]

            # Eliminar las filas de la columna 'cod_ies' que contienen NaN (son las últimas filas que se agregaron por defecto al importar los datos de la planilla excel)
            df_temp = df_temp.dropna(subset=['cod_ies'])

            # Eliminar las filas que no estén asociadas a CFT o IP; en otras palabras, eliminar las filas que contengan registros de Universidades.
            df_temp = df_temp[~df_temp['tipo_inst'].str.contains('Universidad', case=False, na=False)]

            # Verificar si hay duplicados en el índice
            duplicados = df_temp['cod_ies'].duplicated(keep=False)

            if duplicados.any():
                print("> ¡Hay duplicados en el índice!, se debe revisar el dataframe.")
                print(f'> Duplicados: {df_temp[duplicados]}')
            else:
                print("> ¡No hay duplicados en el índice!")
                print(f'> Dataframe: df_temp. Dimensión: {df_temp.shape}')
                df_temp.head(3)
        case 't_info_sii_cft_ip_sies':
            # Extracción de las columnas
            df_temp = df_x_per.iloc[:, [0, 1, 12, 11]]
            
            # Renombrar las columnas del nuevo dataframe
            df_temp.columns = cols
            
            # ELiminar la primera fila del nuevo dataframe que contiene los nombres de las columnas
            df_temp = df_temp.iloc[1:]

            # Eliminar las filas de la columna 'cod_ies' que contienen NaN (son las últimas filas que se agregaron por defecto al importar los datos de la planilla excel)
            df_temp = df_temp.dropna(subset=['cod_ies'])

            # Eliminar las filas que no estén asociadas a CFT o IP; en otras palabras, eliminar las filas que contengan registros de Universidades.
            df_temp = df_temp[~df_temp['tipo_inst'].str.contains('Universidad', case=False, na=False)]

            # Verificar si hay duplicados en el índice
            duplicados = df_temp['cod_ies'].duplicated(keep=False)

            if duplicados.any():
                print("> ¡Hay duplicados en el índice!, se debe revisar el dataframe.")
                print(f'> Duplicados: {df_temp[duplicados]}')
            else:
                print("> ¡No hay duplicados en el índice!")
                print(f'> Dataframe: df_temp. Dimensión: {df_temp.shape}')
                df_temp.head(3)
        case 't_info_acred_cft_ip_sies':
            # Extracción de las columnas. Se repite la columna 'cod_ies' para que coincida con la cantidad de columnas de la lista 'cols'.
            df_temp = df_x_per.iloc[:, [0, 0, 1, 3, 6, 7, 8, 9, 10]]
            
            # Renombrar las columnas del nuevo dataframe
            df_temp.columns = cols
            
            # ELiminar la primera fila del nuevo dataframe que contiene los nombres de las columnas
            df_temp = df_temp.iloc[1:]

            # Eliminar las filas de la columna 'cod_ies' que contienen NaN (son las últimas filas que se agregaron por defecto al importar los datos de la planilla excel)
            df_temp = df_temp.dropna(subset=['cod_ies'])

            # Eliminar las filas que no estén asociadas a CFT o IP; en otras palabras, eliminar las filas que contengan registros de Universidades.
            df_temp = df_temp[~df_temp['tipo_inst'].str.contains('Universidad', case=False, na=False)]

            # Verificar si hay duplicados en el índice
            duplicados = df_temp['cod_ies'].duplicated(keep=False)

            if duplicados.any():
                print("> ¡Hay duplicados en el índice!, se debe revisar el dataframe.")
                print(f'> Duplicados: {df_temp[duplicados]}')
            else:
                print("> ¡No hay duplicados en el índice!")
                print(f'> Dataframe: df_temp. Dimensión: {df_temp.shape}')
                df_temp.head(3)
        case _:
            print('La tabla ingresada no está en la lista!')
    
    return df_temp

# %% [markdown]
# <blockquote>
#     > Dataframe: <b>t_info_gral_cft_ip_sies</b>
#     <ul>
#         <li>Descripción: Dataframe que integrará los registros sin duplicados desde los dataframes [t_instituciones_sies_xxxx_xxxx] por periodos SIES.</li>
#         <li>Columnas: cols_t_info_gral_cft_ip_sies</li>
#     </ul>
# </blockquote>

# %% [markdown]
# ⚠️ Caso especial el dataframe del periodo 2017-2018; queda fuera de la función.

# %%
"""
CASO ESPECIAL
Dataframe: t_info_gral_cft_ip_sies_2017_2018 
Descripción: Dataframe que incluye los registros de la información general de las IES en el periodo 2017-2018.
Columnas: cols_t_info_gral_cft_ip_sies
"""

"""
Perido 2017-2018
"""
# Extracción de las columnas
t_info_gral_cft_ip_sies_2017_2018 = df_instituciones_sies_2017_2018.iloc[:, :6]

# Eliminación de la columna 'Unnamed: 2' asociada al 'Tipo de institución 2' que no está presente en los otros periodos SIES.
# t_info_gral_cft_ip_sies_2017_2018.drop(columns=['Unnamed: 2'], inplace=True)
t_info_gral_cft_ip_sies_2017_2018 = t_info_gral_cft_ip_sies_2017_2018.drop(t_info_gral_cft_ip_sies_2017_2018.columns[2], axis=1)

# Renombrar las columnas del nuevo dataframe
t_info_gral_cft_ip_sies_2017_2018.columns = cols_t_info_gral_cft_ip_sies

# ELiminar la primera fila del nuevo dataframe que contiene los nombres de las columnas 
# (esto ocurrió por defecto al importar los datos de la planilla excel al dataframe)
t_info_gral_cft_ip_sies_2017_2018 = t_info_gral_cft_ip_sies_2017_2018.iloc[1:]

# Eliminar las filas de la columna 'cod_ies' que contienen NaN (son las últimas filas que se agregaron por defecto al importar los datos de la planilla excel)
t_info_gral_cft_ip_sies_2017_2018 = t_info_gral_cft_ip_sies_2017_2018.dropna(subset=['cod_ies'])

# Eliminar las filas que no estén asociadas a CFT o IP; en otras palabras, eliminar las filas que contengan registros de Universidades.
t_info_gral_cft_ip_sies_2017_2018 = t_info_gral_cft_ip_sies_2017_2018[~t_info_gral_cft_ip_sies_2017_2018['tipo_inst'].str.contains('Universidad', case=False, na=False)]

# Verificar si hay duplicados en el índice
duplicados = t_info_gral_cft_ip_sies_2017_2018['cod_ies'].duplicated(keep=False)

if duplicados.any():
    print("> ¡Hay duplicados en el identificador!, se debe revisar el dataframe.")
    print(f'> Duplicados: {t_info_gral_cft_ip_sies_2017_2018[duplicados]}')
else:
    print("> ¡No hay duplicados en el identificador!")
    print(f'> Dataframe: t_instituciones_sies_2017_2018. Dimensión: {t_info_gral_cft_ip_sies_2017_2018.shape}')


t_info_gral_cft_ip_sies_2017_2018.head(3)
# Out:
# > ¡No hay duplicados en el identificador!
# > Dataframe: t_instituciones_sies_2017_2018. Dimensión: (91, 5)
#   cod_ies                     tipo_inst  \
# 1     315  Centros de Formación Técnica
# 2     382  Centros de Formación Técnica
# 3     261  Centros de Formación Técnica
#
#                                 nombre_inst  \
# 1          Centro de Formación Técnica ALFA
# 2         Centro de Formación Técnica Alpes
# 3  Centro de Formación Técnica Andrés Bello
#
#                     dir_sede_central                pag_web
# 1  Avenida Blanco 456 , Constitución         www.cftalfa.cl
# 2   Avda. República Nº 430, Santiago         www.ipalpes.cl
# 3           Las Heras Nº 538, Temuco  www.cftandresbello.cl

# %% [markdown]
# 📞 Llamada a la función para realizar las transoformaciones a los dataframe por periodos.

# %%
"""
Dataframes: 
    - t_info_gral_cft_ip_sies_2018_2019, 
    - t_info_gral_cft_ip_sies_2019_2020, 
    - t_info_gral_cft_ip_sies_2020_2021,
    - t_info_gral_cft_ip_sies_2021_2022,
    - t_info_gral_cft_ip_sies_2023_2024,
    - t_info_gral_cft_ip_sies_2024_2025
Descripción: Dataframes que incluyen (a través de una función) los registros de la infromación general de las IES en los periodos desde 2018 a 2025.
Columnas: cols_t_info_gral_cft_ip_sies
"""

t_info_gral_cft_ip_sies_2018_2019 = procesar_df_instituciones_sies('t_info_gral_cft_ip_sies', df_instituciones_sies_2018_2019, cols_t_info_gral_cft_ip_sies)
t_info_gral_cft_ip_sies_2019_2020 = procesar_df_instituciones_sies('t_info_gral_cft_ip_sies', df_instituciones_sies_2019_2020, cols_t_info_gral_cft_ip_sies)
t_info_gral_cft_ip_sies_2020_2021 = procesar_df_instituciones_sies('t_info_gral_cft_ip_sies', df_instituciones_sies_2020_2021, cols_t_info_gral_cft_ip_sies)
t_info_gral_cft_ip_sies_2021_2022 = procesar_df_instituciones_sies('t_info_gral_cft_ip_sies', df_instituciones_sies_2021_2022, cols_t_info_gral_cft_ip_sies)
t_info_gral_cft_ip_sies_2022_2023 = procesar_df_instituciones_sies('t_info_gral_cft_ip_sies', df_instituciones_sies_2022_2023, cols_t_info_gral_cft_ip_sies)
t_info_gral_cft_ip_sies_2023_2024 = procesar_df_instituciones_sies('t_info_gral_cft_ip_sies', df_instituciones_sies_2023_2024, cols_t_info_gral_cft_ip_sies)
t_info_gral_cft_ip_sies_2024_2025 = procesar_df_instituciones_sies('t_info_gral_cft_ip_sies', df_instituciones_sies_2024_2025, cols_t_info_gral_cft_ip_sies)
# Out:
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (90, 5)
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (86, 5)
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (85, 5)
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (79, 5)
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (76, 5)
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (73, 5)
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (71, 5)

# %% [markdown]
# ℹ️ Muestreo y validación de los registros de los dataframes creados.

# %%
# Muestra de los datos de los dataframe
# t_info_gral_cft_ip_sies_2017_2018
# t_info_gral_cft_ip_sies_2018_2019
# t_info_gral_cft_ip_sies_2019_2020
# t_info_gral_cft_ip_sies_2020_2021
# t_info_gral_cft_ip_sies_2021_2022
# t_info_gral_cft_ip_sies_2022_2023
# t_info_gral_cft_ip_sies_2023_2024
# t_info_gral_cft_ip_sies_2024_2025

print(f'2017-2018: \n{t_info_gral_cft_ip_sies_2017_2018.loc[t_info_gral_cft_ip_sies_2017_2018['cod_ies']==143]}\n')
print(f'2018-2019: \n{t_info_gral_cft_ip_sies_2018_2019.loc[t_info_gral_cft_ip_sies_2018_2019['cod_ies']==143]}\n')
print(f'2019-2020: \n{t_info_gral_cft_ip_sies_2019_2020.loc[t_info_gral_cft_ip_sies_2019_2020['cod_ies']==143]}\n')
print(f'2020-2021: \n{t_info_gral_cft_ip_sies_2020_2021.loc[t_info_gral_cft_ip_sies_2020_2021['cod_ies']==143]}\n')
print(f'2021-2022: \n{t_info_gral_cft_ip_sies_2021_2022.loc[t_info_gral_cft_ip_sies_2021_2022['cod_ies']==143]}\n')
print(f'2022-2023: \n{t_info_gral_cft_ip_sies_2022_2023.loc[t_info_gral_cft_ip_sies_2022_2023['cod_ies']==143]}\n')
print(f'2023-2024: \n{t_info_gral_cft_ip_sies_2023_2024.loc[t_info_gral_cft_ip_sies_2023_2024['cod_ies']==143]}\n')
print(f'2024-2025: \n{t_info_gral_cft_ip_sies_2024_2025.loc[t_info_gral_cft_ip_sies_2024_2025['cod_ies']==143]}\n')
# Out:
# 2017-2018:
#    cod_ies                 tipo_inst                 nombre_inst  \
# 51     143  Institutos Profesionales  Instituto Profesional AIEP
#
#                     dir_sede_central      pag_web
# 51  Av. Providencia N° 729, Santiago  www.aiep.cl
#
# 2018-2019:
#    cod_ies                 tipo_inst                 nombre_inst  \
# 50     143  Institutos Profesionales  Instituto Profesional AIEP
#
#                     dir_sede_central      pag_web
# 50  Av. Providencia N° 729, Santiago  www.aiep.cl
#
# 2019-2020:
#    cod_ies                 tipo_inst                 nombre_inst  \
# 77     143  Institutos Profesionales  Instituto Profesional AIEP
#
#                 dir_sede_central      pag_web
# 77  Bellavista 0121, Providencia  www.aiep.cl
#
# 2020-2021:
#    cod_ies                 tipo_inst                 nombre_inst  \
# 73     143  Institutos Profesionales  Instituto Profesional AIEP
#
#                 dir_sede_central      pag_web
# ...

# %% [markdown]
# ℹ️ Concatenación de los dataframe que contienen la información general de las instituciones (CFT e IP) de los periodos SIES a analizar.

# %%
"""
Dataframe: t_info_gral_cft_ip_sies
Descripción: Dataframe que concatena los dataframe con la información general de las IES por periodo. Toma de base el dataframe del periodo más actual (2024-2025) e 
incorpora los registros que no estén presentes en este periodo con el fin de tener la información histórica de todas las IES (CFT e IP).
"""

# Creación de una lista que contiene todos los dataframes procesados por periodo.
dataframes = [
    t_info_gral_cft_ip_sies_2017_2018, t_info_gral_cft_ip_sies_2018_2019, t_info_gral_cft_ip_sies_2019_2020, t_info_gral_cft_ip_sies_2020_2021, 
    t_info_gral_cft_ip_sies_2021_2022, t_info_gral_cft_ip_sies_2022_2023, t_info_gral_cft_ip_sies_2023_2024, t_info_gral_cft_ip_sies_2024_2025
    ]

# Concatenación de todos los dataframes
df_concatenado = pd.concat(dataframes)

# Eliminación de duplicados basándose en la columna 'cod_ies'
df_concatenado = df_concatenado.drop_duplicates(subset='cod_ies', keep='first')

# Seleccionar solo las filas del dataframe 't_instituciones_sies_2024_2025'
df_2024_2025 = t_info_gral_cft_ip_sies_2024_2025[cols_t_info_gral_cft_ip_sies]

# Concatenación del dataframe 't_info_gral_cft_ip_sies_2024_2025' con el dataframe sin duplicados
t_info_gral_cft_ip_sies = pd.concat([df_2024_2025, df_concatenado]).drop_duplicates(subset='cod_ies', keep='first')

# Dimensión del dataframe resultante
t_info_gral_cft_ip_sies.shape
# Out:
# (108, 5)

# %% [markdown]
# ℹ️ Muestreo y validación de los registros del dataframe creado luego de la concatenación.

# %%
# Muestra de los datos
t_info_gral_cft_ip_sies.loc[t_info_gral_cft_ip_sies['cod_ies']==143]
# Out:
#    cod_ies                 tipo_inst                 nombre_inst  \
# 42     143  Institutos Profesionales  Instituto Profesional AIEP
#
#                 dir_sede_central      pag_web
# 42  Bellavista 0121, Providencia  www.aiep.cl

# %% [markdown]
# <blockquote>
#     > Dataframe: <b>t_info_sii_cft_ip_sies</b>
#     <ul>
#         <li>Descripción: Dataframe que integra los registros sin duplicados desde los dataframes [t_instituciones_sies_xxxx_xxxx] por periodos SIES.</li>
#         <li>Columnas: cols_t_info_sii_cft_ip_sies</li>
#     </ul>
# </blockquote>

# %% [markdown]
# ℹ️ LLamada a la función que procesa los dataframes que contienen información del SII por periodos.

# %%
"""
Dataframes: 
    - t_info_sii_cft_ip_sies_2017_2018, 
    - t_info_sii_cft_ip_sies_2018_2019, 
    - t_info_sii_cft_ip_sies_2019_2020, 
    - t_info_sii_cft_ip_sies_2020_2021,
    - t_info_sii_cft_ip_sies_2021_2022,
    - t_info_sii_cft_ip_sies_2023_2024,
    - t_info_sii_cft_ip_sies_2024_2025
Descripción: Dataframes que incluyen (a través de una función) los registros de la infromación del SII de las IES en los periodos desde 2018 a 2025.
Columnas: cols_t_info_sii_cft_ip_sies
"""

t_info_sii_cft_ip_sies_2017_2018 = procesar_df_instituciones_sies('t_info_sii_cft_ip_sies', df_instituciones_sies_2017_2018, cols_t_info_sii_cft_ip_sies)
t_info_sii_cft_ip_sies_2018_2019 = procesar_df_instituciones_sies('t_info_sii_cft_ip_sies', df_instituciones_sies_2018_2019, cols_t_info_sii_cft_ip_sies)
t_info_sii_cft_ip_sies_2019_2020 = procesar_df_instituciones_sies('t_info_sii_cft_ip_sies', df_instituciones_sies_2019_2020, cols_t_info_sii_cft_ip_sies)
t_info_sii_cft_ip_sies_2020_2021 = procesar_df_instituciones_sies('t_info_sii_cft_ip_sies', df_instituciones_sies_2020_2021, cols_t_info_sii_cft_ip_sies)
t_info_sii_cft_ip_sies_2021_2022 = procesar_df_instituciones_sies('t_info_sii_cft_ip_sies', df_instituciones_sies_2021_2022, cols_t_info_sii_cft_ip_sies)
t_info_sii_cft_ip_sies_2022_2023 = procesar_df_instituciones_sies('t_info_sii_cft_ip_sies', df_instituciones_sies_2022_2023, cols_t_info_sii_cft_ip_sies)
t_info_sii_cft_ip_sies_2023_2024 = procesar_df_instituciones_sies('t_info_sii_cft_ip_sies', df_instituciones_sies_2023_2024, cols_t_info_sii_cft_ip_sies)
t_info_sii_cft_ip_sies_2024_2025 = procesar_df_instituciones_sies('t_info_sii_cft_ip_sies', df_instituciones_sies_2024_2025, cols_t_info_sii_cft_ip_sies)
# Out:
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (91, 4)
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (90, 4)
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (86, 4)
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (85, 4)
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (79, 4)
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (76, 4)
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (73, 4)
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (71, 4)

# %% [markdown]
# ℹ️ Muestreo y validación de los registros de los dataframes creados.

# %%
# Muestra de los datos de los dataframe
# t_info_sii_cft_ip_sies_2017_2018
# t_info_sii_cft_ip_sies_2018_2019
# t_info_sii_cft_ip_sies_2019_2020
# t_info_sii_cft_ip_sies_2020_2021
# t_info_sii_cft_ip_sies_2021_2022
# t_info_sii_cft_ip_sies_2022_2023
# t_info_sii_cft_ip_sies_2023_2024
# t_info_sii_cft_ip_sies_2024_2025

print(f'2017-2018: \n{t_info_sii_cft_ip_sies_2017_2018.loc[t_info_sii_cft_ip_sies_2017_2018['cod_ies']==143]}\n')
print(f'2018-2019: \n{t_info_sii_cft_ip_sies_2018_2019.loc[t_info_sii_cft_ip_sies_2018_2019['cod_ies']==143]}\n')
print(f'2019-2020: \n{t_info_sii_cft_ip_sies_2019_2020.loc[t_info_sii_cft_ip_sies_2019_2020['cod_ies']==143]}\n')
print(f'2020-2021: \n{t_info_sii_cft_ip_sies_2020_2021.loc[t_info_sii_cft_ip_sies_2020_2021['cod_ies']==143]}\n')
print(f'2021-2022: \n{t_info_sii_cft_ip_sies_2021_2022.loc[t_info_sii_cft_ip_sies_2021_2022['cod_ies']==143]}\n')
print(f'2022-2023: \n{t_info_sii_cft_ip_sies_2022_2023.loc[t_info_sii_cft_ip_sies_2022_2023['cod_ies']==143]}\n')
print(f'2023-2024: \n{t_info_sii_cft_ip_sies_2023_2024.loc[t_info_sii_cft_ip_sies_2023_2024['cod_ies']==143]}\n')
print(f'2024-2025: \n{t_info_sii_cft_ip_sies_2024_2025.loc[t_info_sii_cft_ip_sies_2024_2025['cod_ies']==143]}\n')
# Out:
# 2017-2018:
#    cod_ies                 tipo_inst       rut_ies          tipo_soc
# 51     143  Institutos Profesionales  96.621.640-9  Sociedad Anónima
#
# 2018-2019:
#    cod_ies                 tipo_inst       rut_ies               tipo_soc
# 50     143  Institutos Profesionales  96.621.640-9  Sociedad por Acciones
#
# 2019-2020:
#    cod_ies                 tipo_inst       rut_ies               tipo_soc
# 77     143  Institutos Profesionales  96.621.640-9  Sociedad por Acciones
#
# 2020-2021:
#    cod_ies                 tipo_inst       rut_ies               tipo_soc
# 73     143  Institutos Profesionales  96.621.640-9  Sociedad por Acciones
#
# 2021-2022:
#    cod_ies                 tipo_inst       rut_ies               tipo_soc
# 71     143  Institutos Profesionales  96.621.640-9  Sociedad por Acciones
#
# 2022-2023:
#    cod_ies                 tipo_inst       rut_ies               tipo_soc
# 47     143  Institutos Profesionales  96.621.640-9  Sociedad por Acciones
#
# ...

# %% [markdown]
# ℹ️ Concatenación de los dataframe que contienen la información del SII de las instituciones (CFT e IP) de los periodos SIES a analizar.

# %%
"""
Dataframe: t_info_sii_cft_ip_sies
Descripción: Dataframe que concatena los dataframe con la información del SII de las IES por periodo. Toma de base el dataframe del periodo más actual (2024-2025) e 
incorpora los registros que no estén presentes en este periodo con el fin de tener la información histórica de todas las IES (CFT e IP).
"""

# Creación de una lista que contiene todos los dataframes procesados por periodo.
dataframes = [
    t_info_sii_cft_ip_sies_2017_2018, t_info_sii_cft_ip_sies_2018_2019, t_info_sii_cft_ip_sies_2019_2020, t_info_sii_cft_ip_sies_2020_2021, 
    t_info_sii_cft_ip_sies_2021_2022, t_info_sii_cft_ip_sies_2022_2023, t_info_sii_cft_ip_sies_2023_2024, t_info_sii_cft_ip_sies_2024_2025
    ]

# Concatenación de todos los dataframes
df_concatenado = pd.concat(dataframes)

# Eliminación de duplicados basándose en la columna 'cod_ies'
df_concatenado = df_concatenado.drop_duplicates(subset='cod_ies', keep='first')

# Seleccionar solo las filas del dataframe 't_info_sii_cft_ip_sies_2024_2025'
df_2024_2025 = t_info_sii_cft_ip_sies_2024_2025[cols_t_info_sii_cft_ip_sies]

# Concatenación del dataframe 't_info_sii_cft_ip_sies_2024_2025' con el dataframe sin duplicados
t_info_sii_cft_ip_sies = pd.concat([df_2024_2025, df_concatenado]).drop_duplicates(subset='cod_ies', keep='first')

# Eliminación de la columna 'tipo_inst' dado que ya está en el dataframe t_info_acred_cft_ip_sies
t_info_sii_cft_ip_sies.drop('tipo_inst', axis=1, inplace=True)

# Dimensión del dataframe resultante
t_info_sii_cft_ip_sies.shape
# Out:
# (108, 3)

# %% [markdown]
# ℹ️ Muestreo y validación de los registros del dataframe final creado con la concatenación.

# %%
# Muestra de los datos
t_info_sii_cft_ip_sies.loc[t_info_sii_cft_ip_sies['cod_ies']==143]
# Out:
#    cod_ies       rut_ies               tipo_soc
# 42     143  96.621.640-9  Sociedad por Acciones

# %% [markdown]
# <blockquote>
#     > Dataframe: <b>t_info_acred_cft_ip_sies</b>
#     <ul>
#         <li>Descripción: Dataframe que integra los registros sin duplicados desde los dataframes [t_info_acred_cft_ip_sies_xxxx_xxxx] por periodos SIES.</li>
#         <li>Columnas: cols_t_info_acred_cft_ip_sies</li>
#     </ul>
# </blockquote>

# %% [markdown]
# ℹ️ Caso especial el dataframe de información de acreditación del periodo 2017-2018; queda fuera de la función.

# %%
"""
CASO ESPECIAL
Dataframe: t_info_acred_cft_ip_sies_2017_2018 
Descripción: Dataframe que incluye los registros de la información de acreditación de las IES en el periodo 2017-2018.
Columnas: cols_t_info_acred_cft_ip_sies
"""

"""
Perido 2017-2018
"""
# Extracción de las columnas
t_info_acred_cft_ip_sies_2017_2018 = df_instituciones_sies_2017_2018.iloc[:, [0, 0, 1, 3, 6, 7, 8, 9, 10]]

# Renombrar las columnas del nuevo dataframe
t_info_acred_cft_ip_sies_2017_2018.columns = cols_t_info_acred_cft_ip_sies

# Reasignar el valor del periodo SIES a la primera columna 'per_sies' que tenía los datos de cod_ies.
t_info_acred_cft_ip_sies_2017_2018.loc[:, 'per_sies'] = '2017-2018'

# Reasignar el valor de la situación de autonomía como en la columna 'situa_auton' que no presenta datos en este periodo..
t_info_acred_cft_ip_sies_2017_2018.loc[:, 'situa_auton'] = np.nan

# ELiminar la primera fila del nuevo dataframe que contiene los nombres de las columnas 
t_info_acred_cft_ip_sies_2017_2018 = t_info_acred_cft_ip_sies_2017_2018.iloc[1:]

# Eliminar las filas de la columna 'cod_ies' que contienen NaN (son las últimas filas que se agregaron por defecto al importar los datos de la planilla excel)
t_info_acred_cft_ip_sies_2017_2018 = t_info_acred_cft_ip_sies_2017_2018.dropna(subset=['cod_ies'])

# Eliminar las filas que no estén asociadas a CFT o IP; en otras palabras, eliminar las filas que contengan registros de Universidades.
t_info_acred_cft_ip_sies_2017_2018 = t_info_acred_cft_ip_sies_2017_2018[~t_info_acred_cft_ip_sies_2017_2018['tipo_inst'].str.contains('Universidad', case=False, na=False)]

# Verificar si hay duplicados en el índice
duplicados = t_info_acred_cft_ip_sies_2017_2018['cod_ies'].duplicated(keep=False)

if duplicados.any():
    print("> ¡Hay duplicados en el identificador!, se debe revisar el dataframe.")
    print(f'> Duplicados: {t_info_acred_cft_ip_sies_2017_2018[duplicados]}')
else:
    print("> ¡No hay duplicados en el identificador!")
    print(f'> Dataframe: t_instituciones_sies_2017_2018. Dimensión: {t_info_acred_cft_ip_sies_2017_2018.shape}')
    t_info_acred_cft_ip_sies_2017_2018.head(3)
# Out:
# > ¡No hay duplicados en el identificador!
# > Dataframe: t_instituciones_sies_2017_2018. Dimensión: (91, 9)

# %% [markdown]
# 📞 Llamada a la función que procesa los dataframes que contienen información de acreditación institucional por periodos.

# %%
"""
Dataframes: 
    - t_info_acred_cft_ip_sies_2018_2019, 
    - t_info_acred_cft_ip_sies_2019_2020, 
    - t_info_acred_cft_ip_sies_2020_2021,
    - t_info_acred_cft_ip_sies_2021_2022,
    - t_info_acred_cft_ip_sies_2023_2024,
    - t_info_acred_cft_ip_sies_2024_2025
Descripción: Dataframes que incluyen (a través de una función) los registros de la infromación de acreditación de las IES en los periodos desde 2018 a 2025.
Columnas: cols_t_info_acred_cft_ip_sies
"""

# LLamar a la función para realizar las transformaciones.
t_info_acred_cft_ip_sies_2018_2019 = procesar_df_instituciones_sies('t_info_acred_cft_ip_sies', df_instituciones_sies_2018_2019, cols_t_info_acred_cft_ip_sies)
t_info_acred_cft_ip_sies_2019_2020 = procesar_df_instituciones_sies('t_info_acred_cft_ip_sies', df_instituciones_sies_2019_2020, cols_t_info_acred_cft_ip_sies)
t_info_acred_cft_ip_sies_2020_2021 = procesar_df_instituciones_sies('t_info_acred_cft_ip_sies', df_instituciones_sies_2020_2021, cols_t_info_acred_cft_ip_sies)
t_info_acred_cft_ip_sies_2021_2022 = procesar_df_instituciones_sies('t_info_acred_cft_ip_sies', df_instituciones_sies_2021_2022, cols_t_info_acred_cft_ip_sies)
t_info_acred_cft_ip_sies_2022_2023 = procesar_df_instituciones_sies('t_info_acred_cft_ip_sies', df_instituciones_sies_2022_2023, cols_t_info_acred_cft_ip_sies)
t_info_acred_cft_ip_sies_2023_2024 = procesar_df_instituciones_sies('t_info_acred_cft_ip_sies', df_instituciones_sies_2023_2024, cols_t_info_acred_cft_ip_sies)
t_info_acred_cft_ip_sies_2024_2025 = procesar_df_instituciones_sies('t_info_acred_cft_ip_sies', df_instituciones_sies_2024_2025, cols_t_info_acred_cft_ip_sies)
# Out:
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (90, 9)
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (86, 9)
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (85, 9)
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (79, 9)
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (76, 9)
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (73, 9)
# > ¡No hay duplicados en el índice!
# > Dataframe: df_temp. Dimensión: (71, 9)

# %% [markdown]
# ℹ️ Reasignación de los valores de la columna 'per_sies' para uniformar los registros.

# %%
# Reasignar el valor del periodo SIES a la primera columna 'per_sies' que tenía los datos de cod_ies.
t_info_acred_cft_ip_sies_2018_2019.loc[:, 'per_sies'] = '2018-2019'
t_info_acred_cft_ip_sies_2019_2020.loc[:, 'per_sies'] = '2019_2020'
t_info_acred_cft_ip_sies_2020_2021.loc[:, 'per_sies'] = '2020_2021'
t_info_acred_cft_ip_sies_2021_2022.loc[:, 'per_sies'] = '2021_2022'
t_info_acred_cft_ip_sies_2022_2023.loc[:, 'per_sies'] = '2022_2023'
t_info_acred_cft_ip_sies_2023_2024.loc[:, 'per_sies'] = '2023_2024'
t_info_acred_cft_ip_sies_2024_2025.loc[:, 'per_sies'] = '2024_2025'

# %% [markdown]
# ℹ️ Muestreo y validación de los registros de los dataframes creados.

# %%
# Muestra de los datos de los dataframe
# t_info_acred_cft_ip_sies_2017_2018
# t_info_acred_cft_ip_sies_2018_2019
# t_info_acred_cft_ip_sies_2019_2020
# t_info_acred_cft_ip_sies_2020_2021
# t_info_acred_cft_ip_sies_2021_2022
# t_info_acred_cft_ip_sies_2022_2023
# t_info_acred_cft_ip_sies_2023_2024
# t_info_acred_cft_ip_sies_2024_2025

# Verificación de los datos
print(f'2017-2018: \n{t_info_acred_cft_ip_sies_2017_2018.loc[t_info_acred_cft_ip_sies_2017_2018['cod_ies']==143]}\n')
print(f'2018-2019: \n{t_info_acred_cft_ip_sies_2018_2019.loc[t_info_acred_cft_ip_sies_2018_2019['cod_ies']==143]}\n')
print(f'2019-2020: \n{t_info_acred_cft_ip_sies_2019_2020.loc[t_info_acred_cft_ip_sies_2019_2020['cod_ies']==143]}\n')
print(f'2020-2021: \n{t_info_acred_cft_ip_sies_2020_2021.loc[t_info_acred_cft_ip_sies_2020_2021['cod_ies']==143]}\n')
print(f'2021-2022: \n{t_info_acred_cft_ip_sies_2021_2022.loc[t_info_acred_cft_ip_sies_2021_2022['cod_ies']==143]}\n')
print(f'2022-2023: \n{t_info_acred_cft_ip_sies_2022_2023.loc[t_info_acred_cft_ip_sies_2022_2023['cod_ies']==143]}\n')
print(f'2023-2024: \n{t_info_acred_cft_ip_sies_2023_2024.loc[t_info_acred_cft_ip_sies_2023_2024['cod_ies']==143]}\n')
print(f'2024-2025: \n{t_info_acred_cft_ip_sies_2024_2025.loc[t_info_acred_cft_ip_sies_2024_2025['cod_ies']==143]}\n')
# Out:
# 2017-2018:
#      per_sies cod_ies                 tipo_inst situa_auton situa_acred  \
# 51  2017-2018     143  Institutos Profesionales         NaN  Acreditada
#
#    anios_acred                                        perio_acred  \
# 51           4  Desde 22 de octubre de 2017 hasta 22 de octubr...
#
#                                areas_oblig_acred areas_elect_acred
# 51  Gestión Institucional y Docencia de Pregrado               NaN
#
# 2018-2019:
#      per_sies cod_ies                 tipo_inst situa_auton situa_acred  \
# 50  2018-2019     143  Institutos Profesionales    Autónoma  Acreditada
#
#    anios_acred                                        perio_acred  \
# 50           5  Desde 22 de octubre de 2017 hasta 22 de octubr...
#
#                                areas_oblig_acred areas_elect_acred
# 50  Gestión Institucional y Docencia de Pregrado               NaN
#
# 2019-2020:
#      per_sies cod_ies                 tipo_inst situa_auton situa_acred  \
# ...

# %% [markdown]
# ℹ️ Concatenación de los dataframe que contienen la información de acreditación de las instituciones (CFT e IP) de los periodos SIES a analizar.

# %%
"""
Dataframe: t_info_acred_cft_ip_sies
Descripción: Dataframe que concatena los dataframe con la información de acreditación de las IES por periodo. Toma de base el dataframe del periodo más actual (2024-2025) e 
incorpora los registros que no estén presentes en este periodo con el fin de tener la información histórica de todas las IES (CFT e IP).
"""

# Creación de una lista que contiene todos los dataframes procesados por periodo.
dataframes = [
    t_info_acred_cft_ip_sies_2017_2018, t_info_acred_cft_ip_sies_2018_2019, t_info_acred_cft_ip_sies_2019_2020, t_info_acred_cft_ip_sies_2020_2021, 
    t_info_acred_cft_ip_sies_2021_2022, t_info_acred_cft_ip_sies_2022_2023, t_info_acred_cft_ip_sies_2023_2024, t_info_acred_cft_ip_sies_2024_2025
    ]

# Concatenación de todos los dataframes
df_concatenado = pd.concat(dataframes)

# Eliminación de duplicados basándose en la columna 'cod_ies'
df_concatenado = df_concatenado.drop_duplicates(subset='cod_ies', keep='first')

# Seleccionar solo las filas del dataframe 't_info_acred_cft_ip_sies_2024_2025'
df_2024_2025 = t_info_acred_cft_ip_sies_2024_2025[cols_t_info_acred_cft_ip_sies]

# Concatenación del dataframe 't_info_acred_cft_ip_sies_2024_2025' con el dataframe sin duplicados
t_info_acred_cft_ip_sies = pd.concat([df_2024_2025, df_concatenado]).drop_duplicates(subset='cod_ies', keep='first')

# Eliminación de la columna 'tipo_inst' dado que ya está en el dataframe t_info_acred_cft_ip_sies
t_info_acred_cft_ip_sies.drop('tipo_inst', axis=1, inplace=True)

# Dimensión del dataframe resultante
t_info_acred_cft_ip_sies.shape
# Out:
# (108, 8)

# %% [markdown]
# ℹ️ Muestreo y validación de los registros del dataframe final creado con la concatenación.

# %%
# Muestra de los datos
t_info_acred_cft_ip_sies.loc[t_info_acred_cft_ip_sies['cod_ies']==143]
# Out:
#      per_sies cod_ies situa_auton situa_acred anios_acred  \
# 42  2024_2025     143    Autónoma  Acreditada           5
#
#                                           perio_acred  \
# 42  Desde 23 de octubre de 2022 hasta 23 de octubr...
#
#                    areas_oblig_acred         areas_elect_acred
# 42  Gestión Institucional y Docencia  Vinculación con el Medio

# %% [markdown]
# ---

# %% [markdown]
# ⚡ **[procesar_df_pac_sies]**: Función que permite modularizar las operaciones relacionadas con las transformaciones y creación de los dataframes con información del personal académico de las IES (CFT e IP).

# %%
def procesar_df_pac_sies(tabla, df_x_per, cols):
    match tabla:
        case "t_pac_num_cft_ip_sies":
            # Extracción de las columnas
            df_temp = df_x_per.iloc[:, :64]

            # Eliminación de las columnas que no se utilizarán para el análisis.
            df_temp.drop(df_temp.columns[[2, 4, 5]], axis=1, inplace=True)
            df_temp.drop(df_temp.columns[12:24], axis=1, inplace=True)

            # Renombrar las columnas del nuevo dataframe
            df_temp.columns = cols

            # ELiminar las 2 primeras filas del nuevo dataframe que contienen vacíos y los nombres de las columnas
            # (esto ocurrió por defecto al importar los datos de la planilla excel al dataframe)
            df_temp = df_temp.iloc[2:]

            # Eliminar las filas que no estén asociadas a CFT o IP; en otras palabras, eliminar las filas que contengan registros de Universidades.
            df_temp = df_temp[
                ~df_temp["tipo_inst"].str.contains("Universidad", case=False, na=False)
            ]

            print(f"> Dataframe: [t_pac_num_cft_ip_sies]. Dimensión: {df_temp.shape}\n")
            df_temp.head(3)
        case "t_pac_jce_cft_ip_sies":
            # Extracción de las columnas
            df_temp = df_x_per.iloc[:, :60]

            # Eliminación de las columnas que no se utilizarán para el análisis.
            df_temp.drop(df_temp.columns[[2, 4, 5]], axis=1, inplace=True)
            df_temp.drop(df_temp.columns[12:24], axis=1, inplace=True)

            # Renombrar las columnas del nuevo dataframe
            df_temp.columns = cols

            # ELiminar las 2 primeras filas del nuevo dataframe que contienen vacíos y los nombres de las columnas
            # (esto ocurrió por defecto al importar los datos de la planilla excel al dataframe)
            df_temp = df_temp.iloc[2:]

            # Eliminar las filas que no estén asociadas a CFT o IP; en otras palabras, eliminar las filas que contengan registros de Universidades.
            df_temp = df_temp[
                ~df_temp["tipo_inst"].str.contains("Universidad", case=False, na=False)
            ]

            print(f"> Dataframe: [t_pac_num_cft_ip_sies]. Dimensión: {df_temp.shape}\n")
            df_temp.head(3)

    return df_temp

# %% [markdown]
# <blockquote>
#     > Dataframe: <b>t_pac_num_cft_ip_sies</b>
#     <ul>
#         <li>Descripción: Dataframe que integra los registros sin duplicados desde el dataframe [df_pac_num_sies_2017_2024] por periodos SIES.</li>
#         <li>Columnas: cols_t_pac_num_sies</li>
#     </ul>
# </blockquote>

# %% [markdown]
# 📞 Llamada a la función que procesa los dataframes que contienen información del número de Personal Académico por periodos.

# %%
"""
Dataframe: t_pac_num_cft_ip_sies, 
Descripción: Dataframe que incluye (a través de una función) los registros de la información del número del Personal Académico de las IES (CFT e IP) en los periodos desde 2017 a 2024.
Columna: cols_t_pac_num_cft_ip_sies
"""

# LLamada a la función para realizar las transformaciones.
t_pac_num_cft_ip_sies = procesar_df_pac_sies('t_pac_num_cft_ip_sies', df_pac_num_sies_2017_2024, cols_t_pac_num_sies)
# Out:
# > Dataframe: [t_pac_num_cft_ip_sies]. Dimensión: (1598, 49)
# C:\Users\Alex\AppData\Local\Temp\ipykernel_7692\2092501620.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp.drop(df_temp.columns[[2, 4, 5]], axis=1, inplace=True)
# C:\Users\Alex\AppData\Local\Temp\ipykernel_7692\2092501620.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp.drop(df_temp.columns[12:24], axis=1, inplace=True)

# %%
# Dimensión
t_pac_num_cft_ip_sies.shape
# Out:
# (1598, 49)

# %%
# Eliminación de la columna 'tipo_inst' dado que ya está en el dataframe t_info_gral_cft_ip_sies
t_pac_num_cft_ip_sies.drop('tipo_inst', axis=1, inplace=True)
t_pac_num_cft_ip_sies.shape
# Out:
# (1598, 48)

# %%
# Filtro de los datos por el periodo SIES
t_pac_num_cft_ip_sies = t_pac_num_cft_ip_sies[(t_pac_num_cft_ip_sies['per_sies'] >= 'PAC_2017') & (t_pac_num_cft_ip_sies['per_sies'] <= 'PAC_2024')]

# Mostrar el resultado filtrado
t_pac_num_cft_ip_sies['per_sies'].value_counts()
# Out:
# per_sies
# PAC_2018    87
# PAC_2017    87
# PAC_2019    85
# PAC_2020    84
# PAC_2022    79
# PAC_2021    79
# PAC_2023    72
# PAC_2024    71
# Name: count, dtype: int64

# %%
# Muestra
t_pac_num_cft_ip_sies.head(3)
# Out:
#     per_sies cod_ies total_mujeres total_hombres total_gral prom_edad_mujeres  \
# 55  PAC_2024      99            21            27         48         46.238095
# 56  PAC_2024     100          1376          2953       4329          44.24782
# 57  PAC_2024     101            18            23         41         46.055556
#
#    prom_edad_hombres prom_edad_inst num_acad_1_inst num_acad_2_inst  ...  \
# 55         49.074074      47.833333               1               8  ...
# 56         46.115814      45.522061             279             448  ...
# 57         42.652174      44.146341               2               5  ...
#
#    num_acad_nac_chile num_acad_nac_extra prom_gral_hrs_acad prom_muj_hrs_acad  \
# 55                 48                NaN            20.0625         21.428571
# 56               4222                107           15.75737         15.796469
# 57                 40                  1           8.756098          8.888889
#
# ...

# %%
# Verificación
t_pac_num_cft_ip_sies[t_pac_num_cft_ip_sies['cod_ies']==143]
# Out:
#       per_sies cod_ies total_mujeres total_hombres total_gral  \
# 72    PAC_2024     143          2437          2504       4941
# 198   PAC_2023     143          2405          2537       4942
# 325   PAC_2022     143          2202          2254       4456
# 458   PAC_2021     143          1931          1982       3913
# 595   PAC_2020     143          2166          2265       4431
# 738   PAC_2019     143          1941          2194       4135
# 884   PAC_2018     143          1846          2194       4040
# 1033  PAC_2017     143          1802          2201       4003
#
#      prom_edad_mujeres prom_edad_hombres prom_edad_inst num_acad_1_inst  \
# 72           40.125564         42.799521      41.480672             786
# 198           39.82578         42.234923      41.062525             812
# 325          39.523615         41.999556      40.776032             803
# 458          39.746763         42.243189      41.011245             681
# ...

# %% [markdown]
# <blockquote>
#     > Dataframe: <b>t_pac_jce_cft_ip_sies</b>
#     <ul>
#         <li>Descripción: Dataframe que integra los registros sin duplicados desde el dataframe [df_pac_jce_sies_2017_2024] por periodos SIES.</li>
#         <li>Columnas: cols_t_pac_jce_sies</li>
#     </ul>
# </blockquote>

# %% [markdown]
# 📞 Llamada a la función que procesa los dataframes que contienen información de las JCE de Personal Académico por periodos.

# %%
"""
Dataframe: t_pac_jce_cft_ip_sies, 
Descripción: Dataframe que incluye (a través de una función) los registros de la información de las JCE del Personal Académico de las IES (CFT e IP) en los periodos desde 2017 a 2024.
Columna: cols_t_pac_jce_cft_ip_sies
"""

# LLamada a la función para realizar las transformaciones.
t_pac_jce_cft_ip_sies = procesar_df_pac_sies('t_pac_jce_cft_ip_sies', df_pac_jce_sies_2017_2024, cols_t_pac_jce_sies)
# Out:
# > Dataframe: [t_pac_num_cft_ip_sies]. Dimensión: (1598, 45)
# C:\Users\Alex\AppData\Local\Temp\ipykernel_7692\2092501620.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp.drop(df_temp.columns[[2, 4, 5]], axis=1, inplace=True)
# C:\Users\Alex\AppData\Local\Temp\ipykernel_7692\2092501620.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp.drop(df_temp.columns[12:24], axis=1, inplace=True)

# %% [markdown]
# ℹ️ Validación y obtención de la dimensión del dataframe.

# %%
# Dimensión
t_pac_jce_cft_ip_sies.shape
# Out:
# (1598, 45)

# %% [markdown]
# ℹ️ Eliminación de una columna y verificación de la dimensión.

# %%
# Eliminación de la columna 'tipo_inst' dado que ya está en el dataframe t_info_gral_cft_ip_sies
t_pac_jce_cft_ip_sies.drop('tipo_inst', axis=1, inplace=True)
t_pac_jce_cft_ip_sies.shape
# Out:
# (1598, 44)

# %% [markdown]
# ℹ️ FIltrado por los periodos de estudio y verificación de los registros del dataset.

# %%
# Filtro de los datos por el periodo SIES
t_pac_jce_cft_ip_sies = t_pac_jce_cft_ip_sies[(t_pac_jce_cft_ip_sies['per_sies'] >= 'PAC_2017') & (t_pac_jce_cft_ip_sies['per_sies'] <= 'PAC_2024')]

# Mostrar el resultado filtrado
t_pac_jce_cft_ip_sies['per_sies'].value_counts()
# Out:
# per_sies
# PAC_2018    87
# PAC_2017    87
# PAC_2019    85
# PAC_2020    84
# PAC_2022    79
# PAC_2021    79
# PAC_2023    72
# PAC_2024    71
# Name: count, dtype: int64

# %%
# Muestra
t_pac_jce_cft_ip_sies.tail(3)
# Out:
#       per_sies cod_ies total_jce_mujeres total_jce_hombres total_jce_gral  \
# 1095  PAC_2017     754          1.204545          7.204545       8.409091
# 1096  PAC_2017     767          3.818182          3.647727       7.465909
# 1097  PAC_2017     782          0.545455          1.977273       2.522727
#
#      prom_edad_jce_mujeres prom_edad_jce_hombres prom_edad_jce_inst  \
# 1095             66.075472             64.321767          64.572973
# 1096             28.232143             35.149533          31.611872
# 1097             32.166667             43.436782                 41
#
#      num_jce_1_inst num_jce_2_inst  ... num_jce_reg_losla num_jce_reg_aysen  \
# 1095            NaN       0.113636  ...               NaN               NaN
# 1096       3.681818       0.068182  ...               NaN               NaN
# 1097       0.545455            NaN  ...               NaN               NaN
#
#      num_jce_reg_magal num_jce_reg_sin_inf num_jce_nac_chile  \
# ...

# %% [markdown]
# ℹ️ Muestreo y verificación de los registros del dataset.

# %%
# Verificación
t_pac_jce_cft_ip_sies[t_pac_jce_cft_ip_sies['cod_ies']==143]
# Out:
#       per_sies cod_ies total_jce_mujeres total_jce_hombres total_jce_gral  \
# 72    PAC_2024     143       1395.909091       1375.386364    2771.295455
# 198   PAC_2023     143       1307.727273       1358.227273    2665.954545
# 325   PAC_2022     143       1194.863636       1236.681818    2431.545455
# 458   PAC_2021     143        834.204545        841.818182    1676.022727
# 595   PAC_2020     143       1220.409091       1224.636364    2445.045455
# 738   PAC_2019     143        953.227273       1164.022727        2117.25
# 884   PAC_2018     143        840.818182            1084.5    1925.318182
# 1033  PAC_2017     143        892.842172       1193.137626    2085.979798
#
#      prom_edad_jce_mujeres prom_edad_jce_hombres prom_edad_jce_inst  \
# 72               40.091892             43.482757          41.774769
# 198              40.380553             43.460359          41.949626
# 325              40.101723             43.058202          41.605386
# ...

# %% [markdown]
# <blockquote>
#     > Dataframe: <b>t_info_carreras_cft_ip_sies</b>
#     <ul>
#         <li>Descripción: Dataframe que contiene los registros sin duplicados desde el dataframe [df_info_carreras_ipcft_sies_2017_2025] por periodos SIES.</li>
#         <li>Columnas: cols_t_info_carreras_cft_ip_sies</li>
#     </ul>
# </blockquote>

# %% [markdown]
# ⚡ **[asigna_anio_periodo]**: Función que permite asignar el año mayor del periodo a través de la extracción de un valor en una cadena de texto.

# %%
def asigna_anio_periodo(columna, periodo):
    # anio = 0
    match columna:
        case 'anio_arancel_anual_carr':            
            anio = int(periodo.split('-')[1]) # Extraer el año mayor del periodo
        case 'anio_mat_tot_carr':
            anio = int(periodo.split('-')[0]) # Extraer el año menor del periodo
        case 'anio_mat_1er_anio_carr':
            anio = int(periodo.split('-')[0]) # Extraer el año menor del periodo
        case 'anio_tit_carr':
            anio = int(periodo.split('-')[0]) - 1 # Extraer el año menor del periodo menos 1 año
    return anio

# %%
"""
Dataframe: t_info_carreras_cft_ip_sies 
Descripción: Dataframe que incluye los registros de la información de las carreras de las IES en el periodo 2017-2018.
Columnas: cols_t_info_carreras_cft_ip_sies
"""

# Extracción de las columnas
t_info_carreras_cft_ip_sies = df_info_carreras_ipcft_sies_2017_2025.iloc[:, list(range(0, 5)) + list(range(6, 27)) + [29, 30, 39]]

# Renombrar las columnas del nuevo dataframe
t_info_carreras_cft_ip_sies.columns = cols_t_info_carreras_cft_ip_sies

# %% [markdown]
# ℹ️ Muestreo y verificación de los registros del dataset.

# %%
t_info_carreras_cft_ip_sies.tail(3)
# Out:
#         per_sies      cod_carr  cod_sies                   area_con  \
# 56034  2017-2018  I916S1C1J2V1       916  Administración y Comercio
# 56035  2017-2018  I916S1C2J1V1       916                 Tecnología
# 56036  2017-2018  I916S1C2J2V1       916                 Tecnología
#
#                                   tipo_inst  \
# 56034  Centros de Formación Técnica Estatal
# 56035  Centros de Formación Técnica Estatal
# 56036  Centros de Formación Técnica Estatal
#
#                                          nom_carr                reg_carr  \
# 56034  TECNICO EN GESTION Y LOGISTICA EMPRESARIAL  Región de la Araucanía
# 56035    TECNICO EN ELECTRICIDAD Y AUTOMATIZACION  Región de la Araucanía
# 56036    TECNICO EN ELECTRICIDAD Y AUTOMATIZACION  Región de la Araucanía
#
#          jor_carr     sede_carr arancel_anual_carr  ... porc_mat_est_mun  \
# 56034  Vespertino  SEDE LAUTARO            1100000  ...              NaN
# ...

# %% [markdown]
# 📞 Llamada a la función que extrae el año de un perido en una cadena de texto.

# %%
# Crear la nueva columna 'anio_arancel_anual_carr'
t_info_carreras_cft_ip_sies['anio_arancel_anual_carr'] = t_info_carreras_cft_ip_sies['per_sies'].apply(lambda periodo: asigna_anio_periodo('anio_arancel_anual_carr', periodo))

# Crear la nueva columna 'anio_mat_tot_carr'
t_info_carreras_cft_ip_sies['anio_mat_tot_carr'] = t_info_carreras_cft_ip_sies['per_sies'].apply(lambda periodo: asigna_anio_periodo('anio_mat_tot_carr', periodo))

# Crear la nueva columna 'anio_mat_1er_anio_carr'
t_info_carreras_cft_ip_sies['anio_mat_1er_anio_carr'] = t_info_carreras_cft_ip_sies['per_sies'].apply(lambda periodo: asigna_anio_periodo('anio_mat_1er_anio_carr', periodo))

# Crear la nueva columna 'anio_tit_carr'
t_info_carreras_cft_ip_sies['anio_tit_carr'] = t_info_carreras_cft_ip_sies['per_sies'].apply(lambda periodo: asigna_anio_periodo('anio_tit_carr', periodo))
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_7692\4144082935.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_info_carreras_cft_ip_sies['anio_arancel_anual_carr'] = t_info_carreras_cft_ip_sies['per_sies'].apply(lambda periodo: asigna_anio_periodo('anio_arancel_anual_carr', periodo))
# C:\Users\Alex\AppData\Local\Temp\ipykernel_7692\4144082935.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# ℹ️ Muestreo y verificación de los registros del dataset.

# %%
t_info_carreras_cft_ip_sies.tail(3)
# t_info_carreras_cft_ip_sies['anio_mat_tot_carr'].value_counts()
# t_info_carreras_cft_ip_sies.shape
# Out:
#         per_sies      cod_carr  cod_sies                   area_con  \
# 56034  2017-2018  I916S1C1J2V1       916  Administración y Comercio
# 56035  2017-2018  I916S1C2J1V1       916                 Tecnología
# 56036  2017-2018  I916S1C2J2V1       916                 Tecnología
#
#                                   tipo_inst  \
# 56034  Centros de Formación Técnica Estatal
# 56035  Centros de Formación Técnica Estatal
# 56036  Centros de Formación Técnica Estatal
#
#                                          nom_carr                reg_carr  \
# 56034  TECNICO EN GESTION Y LOGISTICA EMPRESARIAL  Región de la Araucanía
# 56035    TECNICO EN ELECTRICIDAD Y AUTOMATIZACION  Región de la Araucanía
# 56036    TECNICO EN ELECTRICIDAD Y AUTOMATIZACION  Región de la Araucanía
#
#          jor_carr     sede_carr arancel_anual_carr  ... tit_tot_fem_carr  \
# 56034  Vespertino  SEDE LAUTARO            1100000  ...                0
# ...

# %% [markdown]
# <blockquote>
#     > Dataframe: <b>t_info_empleabilidad_ipcft_sies_2017_2025</b>
#     <ul>
#         <li>Descripción: Dataframe que contiene los registros desde el dataframe [df_info_empleabilidad_ipcft_sies_2017_2025] por periodos SIES.</li>
#         <li>Columnas: cols_t_info_empleabilidad_ipcft_sies_2017_2025</li>
#     </ul>
# </blockquote>

# %%
# Eliminación de las columnas: Tipo de institución y Nombre de institución que dado que ya está en el dataframe t_info_gral_cft_ip_sies
t_info_empleabilidad_ipcft_sies_2017_2025 = df_info_empleabilidad_ipcft_sies_2017_2025.drop(df_info_empleabilidad_ipcft_sies_2017_2025.columns[[1,2]], axis=1)
t_info_empleabilidad_ipcft_sies_2017_2025.columns
# Out:
# Index(['Código', 'Acreditación institución (al 31 de octubre 2024)', 'Área',
#        'Nombre carrera genérica', 'Nombre carrera (del título)',
#        '% titulados con continuidad de estudios', 'Retención 1er año',
#        'Duración Real (semestres)', 'Empleabilidad 1er año',
#        'Empleabilidad 2° año', 'Ingreso Promedio al 4° año', 'Arancel anual',
#        'Periodo'],
#       dtype='object')

# %%
# Renombrar las columnas del nuevo dataframe
t_info_empleabilidad_ipcft_sies_2017_2025.columns = cols_t_info_empleabilidad_ipcft_sies_2017_2025
t_info_empleabilidad_ipcft_sies_2017_2025.columns
# Out:
# Index(['cod_sies', 'acred_inst', 'area_carr', 'nom_carr_gen', 'nom_carr_tit',
#        'porc_tit_cont_est', 'ret_1er_anio', 'dur_real_carr_sem',
#        'emp_1er_anio_tit_carr', 'emp_2do_anio_tit_carr',
#        'ing_prom_4to_anio_tit', 'arancel_anual_carr', 'per_sies'],
#       dtype='object')

# %% [markdown]
# ℹ️ Muestreo y verificación de los registros del dataset.

# %%
# t_info_empleabilidad_ipcft_sies_2017_2025.head(3)
t_info_empleabilidad_ipcft_sies_2017_2025.tail(3)
# t_info_empleabilidad_ipcft_sies_2017_2025
# Out:
#       cod_sies acred_inst                  area_carr  \
# 4162     116.0     3 años                 Tecnología
# 4163     116.0     3 años          Ciencias Sociales
# 4164     116.0     3 años  Administración y Comercio
#
#                         nom_carr_gen               nom_carr_tit  \
# 4162               Técnico en Sonido          Técnico en Sonido
# 4163      Técnico en Servicio Social  Técnico en Trabajo Social
# 4164  Técnico en Turismo y Hotelería         Técnico en Turismo
#
#       porc_tit_cont_est ret_1er_anio dur_real_carr_sem  emp_1er_anio_tit_carr  \
# 4162                NaN         0.64               s/i               0.450000
# 4163                NaN     0.722519          6.714715               0.454969
# 4164                NaN     0.539326               s/i               0.420118
#
#       emp_2do_anio_tit_carr   ing_prom_4to_anio_tit arancel_anual_carr  \
# 4162                    NaN  De $500 mil a $600 mil            1347625
# ...

# %% [markdown]
# <blockquote>
#     > Dataframes: <b>t_dist</b>, <b>t_dur</b>, <b>t_emp</b>, <b>t_evol_emp</b>, <b>t_evol_ing</b>, <b>t_ipbm</b>, <b>t_mat</b>, <b>t_ret</b>, <b>t_tipbm</b> y <b>t_tit</b>
#     <ul>
#         <li>Descripción: Dataframe que contiene los registros desde varios dataframes de estadísticas por carreras [df_dist, df_dur, df_emp, df_evol_emp, df_evol_ing, df_ipbm, df_mat, df_ret, df_tipbm y df_tit] por periodos SIES.</li>
#         <li>Columnas: cols_df_dist, cols_df_dur, cols_df_emp, cols_df_evol_emp, cols_df_evol_ing, cols_df_ipbm, cols_df_mat, cols_df_ret, cols_df_tipbm y cols_df_tit</li>
#     </ul>
# </blockquote>

# %%
# Creación de los dataframes
t_dist = df_t_dist
t_dur = df_t_dur
t_emp = df_t_emp
t_evol_emp = df_t_evol_emp
t_evol_ing = df_t_evol_ing
t_ipbm = df_t_ipbm
t_mat = df_t_mat
t_ret = df_t_ret
t_tipbm = df_t_tipbm
t_tit = df_t_tit

# %%
# Renombrar las columnas de los dataframe
t_dist.columns = cols_t_dist
t_dur.columns = cols_t_dur
t_emp.columns = cols_t_emp
t_evol_emp.columns = cols_t_evol_emp
t_evol_ing.columns = cols_t_evol_ing
t_ipbm.columns = cols_t_ipbm
t_mat.columns = cols_t_mat
t_ret.columns = cols_t_ret
t_tipbm.columns = cols_t_tipbm
t_tit.columns = cols_t_tit

# %% [markdown]
# ℹ️ Muestreo y verificación de los registros del dataset.

# %%
# t_dist.head(3)
# t_dur.head(3)
# t_emp.head(3)
# t_evol_emp.head(3)
# t_evol_ing.head(3)
# t_ipbm.head(3)
# t_mat.head(3)
t_ret.head(3)
# t_tipbm.head(3)
# t_tit.head(3)
# Out:
#     per_sies  id_carr_gen                  area_carr  \
# 0  2024-2025            1  Administración y Comercio
# 1  2024-2025            3               Agropecuaria
# 2  2024-2025            4                  Educación
#
#                       tipo_inst                                nom_carr_gen  \
# 0  Centros de Formación Técnica                       Secretariado Bilingüe
# 1  Centros de Formación Técnica                        Técnico Agropecuario
# 2  Centros de Formación Técnica  Técnico Asistente del Educador de Párvulos
#
#    coho_mat tasa_ret_1er_anio tasa_ret_2do_anio
# 0      2022          0.742857               s/i
# 1      2022          0.698506               s/i
# 2      2022          0.762731               s/i

# %% [markdown]
# ###### <h5>c) Procesos ETL: Carga (exportación) de los conjuntos de datos.</h5>

# %% [markdown]
# 🖨️ Exportación de dataset **t_info_carreras_cft_ip_sies** correspondiente a la Información de Carreras por Institución SIES CFT e IP del 2017 al 2025.

# %%
t_info_carreras_cft_ip_sies.to_csv('t_info_carreras_cft_ip_sies.csv', sep=';' ,index=False)

# %% [markdown]
# 🖨️ Exportación de dataset **t_info_empleabilidad_ipcft_sies_2017_2025** correspondiente a la Información de Empleabilidad e Ingresos por Institución SIES CFT e IP del 2017 al 2025.

# %%
t_info_empleabilidad_ipcft_sies_2017_2025.to_csv('t_info_empleabilidad_ipcft_sies_2017_2025.csv', sep=';' ,index=False)

# %% [markdown]
# 🖨️ Exportación de los datasets: **t_dist**, **t_dur**, **t_emp**, **t_evol_emp**, **t_evol_ing**, **t_ipbm**, **t_mat**, **t_ret**, **t_tipbm** y **t_tit** correspondiente a las Estadísticas por Carrera SIES CFT e IP del 2017 al 2025.

# %%
t_dist.to_csv('t_dist.csv', sep=';' ,index=False)
t_dur.to_csv('t_dur.csv', sep=';' ,index=False)
t_emp.to_csv('t_emp.csv', sep=';' ,index=False)
t_evol_emp.to_csv('t_evol_emp.csv', sep=';' ,index=False)
t_evol_ing.to_csv('t_evol_ing.csv', sep=';' ,index=False)
t_ipbm.to_csv('t_ipbm.csv', sep=';' ,index=False)
t_mat.to_csv('t_mat.csv', sep=';' ,index=False)
t_ret.to_csv('t_ret.csv', sep=';' ,index=False)
t_tipbm.to_csv('t_tipbm.csv', sep=';' ,index=False)
t_tit.to_csv('t_tit.csv', sep=';' ,index=False)

# %% [markdown]
# 🖨️ Exportación de los datasets **t_info_gral_cft_ip_sies**, **t_info_sii_cft_ip_sies** y **t_info_acred_cft_ip_sies** correspondientes a la Información General, del SII y de la Acreditación de las IES CFT e IP SIES del 2017 al 2025.

# %%
t_info_gral_cft_ip_sies.to_csv('t_info_gral_cft_ip_sies.csv', sep=';' ,index=False)
t_info_sii_cft_ip_sies.to_csv('t_info_sii_cft_ip_sies.csv', sep=';' ,index=False)
t_info_acred_cft_ip_sies.to_csv('t_info_acred_cft_ip_sies.csv', sep=';' ,index=False)

# %% [markdown]
# 🖨️ Exportación de los dataset **t_pac_num_cft_ip_sies** y **t_pac_jce_cft_ip_sies** correspondiente a la Información del Personal Académico (por Número y JCE) de las IES CFT e IP SIES del 2017 al 2025.

# %%
t_pac_num_cft_ip_sies.to_csv('t_pac_num_cft_ip_sies.csv', sep=';' ,index=False)
t_pac_jce_cft_ip_sies.to_csv('t_pac_jce_cft_ip_sies.csv', sep=';' ,index=False)

# %% [markdown]
# ##### 3.3.3 Análisis de Datos.

# %% [markdown]
# <b>A) Análisis Exploratorio de Datos (EDA).</b>

# %% [markdown]
# 1. <b>Carga de datos y configuración inicial.</b><br>
# <blockquote>El primer paso consiste en la carga de los datasets generados en la etapa de preprocesamiento. Se estableció el separador ";" para asegurar una correcta lectura de los archivos.</blockquote>

# %%
# Definir las rutas de los archivos CSV
file_paths = {
    "info_carreras": "t_info_carreras_cft_ip_sies.csv",
    "info_empleabilidad": "t_info_empleabilidad_ipcft_sies_2017_2025.csv",
    "dist": "t_dist.csv",
    "dur": "t_dur.csv",
    "emp": "t_emp.csv",
    "evol_emp": "t_evol_emp.csv",
    "evol_ing": "t_evol_ing.csv",
    "ipbm": "t_ipbm.csv",
    "mat": "t_mat.csv",
    "ret": "t_ret.csv",
    "tipbm": "t_tipbm.csv",
    "tit": "t_tit.csv",
    "info_gral": "t_info_gral_cft_ip_sies.csv",
    "info_sii": "t_info_sii_cft_ip_sies.csv",
    "info_acred": "t_info_acred_cft_ip_sies.csv",
    "pac_num": "t_pac_num_cft_ip_sies.csv",
    "pac_jce": "t_pac_jce_cft_ip_sies.csv",
}

# Cargar los datasets en un diccionario de dataframes
dataframes = {name: pd.read_csv(path, sep=";", low_memory=False) for name, path in file_paths.items()}

# Verificar que la variable existe en el dataset "ret"
if "tasa_ret_1er_anio" in dataframes["ret"].columns:
    print("✅ La variable 'tasa_ret_1er_anio' está correctamente cargada en t_ret.csv")
else:
    print("❌ ERROR: La variable 'tasa_ret_1er_anio' no se encuentra en t_ret.csv")
# Out:
# ✅ La variable 'tasa_ret_1er_anio' está correctamente cargada en t_ret.csv

# %%
# Verificación
# dataframes['ret']['tasa_ret_1er_anio']
dataframes['ret']['tasa_ret_2do_anio'].value_counts()
# dataframes['ret']['tasa_ret_1er_anio'].describe()
# Out:
# tasa_ret_2do_anio
# s/i                    268
# 0.6666666666666666       3
# 0.6391752577319587       2
# 0.6492890995260664       2
# 0.6512820512820513       1
#                       ...
# 0.5830105861089595       1
# 0.6768488745980707       1
# 0.656140350877193        1
# 0.5819935691318328       1
# 0.38808373590982287      1
# Name: count, Length: 334, dtype: int64

# %% [markdown]
# <blockquote>
# <ul>
#     <li>Se cargan todos los datasets en un diccionario de dataframes para facilitar el acceso a cada uno de ellos.</li>
#     <li>Se usa low_memory=False para evitar problemas de carga con archivos grandes.</li>
# </ul>
# </blockquote>

# %% [markdown]
# 2. <b>Inspección inicial de los datos.</b><br>
# <blockquote>
# En esta etapa se revisa la estructura de los datasets, incluyendo:
#     <ul>
#         <li>Número de filas y columnas.</li>
#         <li>Tipos de datos de cada columna.</li>
#         <li>Primeras cinco filas de cada dataset.</li>
#     </ul>
# </blockquote>

# %%
# Obtener información general de cada dataset
for name, df in dataframes.items():
    print(f"\nDataset: {name}")
    print(f"Dimensiones: {df.shape}")
    print("Tipos de datos:")
    print(df.dtypes)
    print("Primeras filas:")
    print(df.head())
    print("-" * 50)
# Out:
# Dataset: info_carreras
# Dimensiones: (56037, 33)
# Tipos de datos:
# per_sies                   object
# cod_carr                   object
# cod_sies                    int64
# area_con                   object
# tipo_inst                  object
# nom_carr                   object
# reg_carr                   object
# jor_carr                   object
# sede_carr                  object
# arancel_anual_carr         object
# costo_tit_carr             object
# dur_form_carr               int64
# niv_carr                   object
# mat_tot_fem_carr            int64
# mat_tot_mas_carr            int64
# mat_tot_carr                int64
# mat_1er_anio_fem_carr       int64
# mat_1er_anio_masc_carr      int64
# mat_tot_1er_anio_carr       int64
# porc_mat_est_mun           object
# porc_mat_est_par_sub       object
# porc_mat_est_par_pag       object
# porc_mat_est_adm           object
# tit_tot_fem_carr            int64
# tit_tot_mas_carr            int64
# ...

# %% [markdown]
# <blockquote>
#     <ul>
#         <li>Se obtiene una visión general de cada dataset.</li>
#         <li>Se identifican posibles problemas como columnas con tipos de datos incorrectos.</li>
#     </ul>
# </blockquote>

# %% [markdown]
# 3. <b>Análisis de valores nulos.</b><br>
# <blockquote>
#     Se identifican las columnas que contienen valores nulos y el porcentaje de celdas vacías en cada una.
# </blockquote>

# %%
# Análisis de valores nulos
null_values = {name: df.isnull().sum().sort_values(ascending=False) for name, df in dataframes.items()}

# Mostrar porcentaje de valores nulos en cada dataset
for name, df in dataframes.items():
    print(f"\nValores Nulos en {name}")
    print((df.isnull().sum() / len(df) * 100).sort_values(ascending=False))
    print("-" * 50)
# Out:
# Valores Nulos en info_carreras
# prom_nem                   15.762800
# porc_mat_est_adm           12.718382
# porc_mat_est_par_pag       12.718382
# porc_mat_est_par_sub       12.718382
# porc_mat_est_mun           12.718382
# area_carr_gen              10.036226
# per_sies                    0.000000
# mat_1er_anio_masc_carr      0.000000
# anio_mat_1er_anio_carr      0.000000
# anio_mat_tot_carr           0.000000
# anio_arancel_anual_carr     0.000000
# vac_1er_sem_carr            0.000000
# tit_tot_carr                0.000000
# tit_tot_mas_carr            0.000000
# tit_tot_fem_carr            0.000000
# mat_tot_1er_anio_carr       0.000000
# mat_1er_anio_fem_carr       0.000000
# cod_carr                    0.000000
# mat_tot_carr                0.000000
# mat_tot_mas_carr            0.000000
# mat_tot_fem_carr            0.000000
# niv_carr                    0.000000
# dur_form_carr               0.000000
# costo_tit_carr              0.000000
# ...

# %% [markdown]
# <blockquote>
#     <ul>
#         <li>Se identifican columnas con altos niveles de valores nulos.</li>
#         <li>Se decide si los valores faltantes se imputarán o si las columnas deben ser eliminadas.</li>
#     </ul>
# </blockquote>

# %% [markdown]
# 4. <b>Imputación de valores nulos y anómalos.</b><br>
# <blockquote>
# Se realiza la imputación de datos faltantes utilizando:
#     <ul>
#         <li>Mediana para valores numéricos.</li>
#         <li>Moda para valores categóricos.</li>
#     </ul>
# </blockquote>

# %%
# Verificación
dataframes['ret'].head(3)
# Out:
#     per_sies  id_carr_gen                  area_carr  \
# 0  2024-2025            1  Administración y Comercio
# 1  2024-2025            3               Agropecuaria
# 2  2024-2025            4                  Educación
#
#                       tipo_inst                                nom_carr_gen  \
# 0  Centros de Formación Técnica                       Secretariado Bilingüe
# 1  Centros de Formación Técnica                        Técnico Agropecuario
# 2  Centros de Formación Técnica  Técnico Asistente del Educador de Párvulos
#
#    coho_mat   tasa_ret_1er_anio tasa_ret_2do_anio
# 0      2022  0.7428571428571429               s/i
# 1      2022  0.6985055230669266               s/i
# 2      2022  0.7627311522048364               s/i

# %%
# Imputación de valores nulos de forma segura y sin errores en columnas vacías
for name, df in dataframes.items():
    df_cleaned = df.copy()  # Crear una copia explícita del DataFrame
    
    # Imputación de valores numéricos con la mediana solo si la columna tiene valores no nulos
    numeric_cols = df_cleaned.select_dtypes(include=['float64', 'int64']).columns
    for col in numeric_cols:
        if df_cleaned[col].notnull().sum() > 0:  # Solo aplicar si hay valores no nulos
            df_cleaned[col] = df_cleaned[col].fillna(df_cleaned[col].median())

    # Imputación de valores categóricos con la moda solo si la columna tiene valores no nulos
    categorical_cols = df_cleaned.select_dtypes(include=['object']).columns
    for col in categorical_cols:
        if df_cleaned[col].notnull().sum() > 0:  # Solo aplicar si hay valores no nulos
            df_cleaned[col] = df_cleaned[col].fillna(df_cleaned[col].mode()[0])

    # Guardar el dataframe procesado en el diccionario
    dataframes[name] = df_cleaned

# %%
# Verificación
dataframes['ret']['tasa_ret_1er_anio'].value_counts()
# dataframes['ret']['tasa_ret_2do_anio'].value_counts()
dataframes['ret']['tasa_ret_1er_anio'].describe()
# Out:
# count     1078
# unique    1008
# top        s/i
# freq        31
# Name: tasa_ret_1er_anio, dtype: object

# %%
# Aplicar transformación en el dataset "t_ret" con validación de valores negativos
if "ret" in dataframes:
    df = dataframes["ret"].copy()  # Crear copia para evitar modificar el original

    # Definir las columnas objetivo a limpiar
    target_columns = ["tasa_ret_1er_anio", "tasa_ret_2do_anio"]

    for col in target_columns:
        if col in df.columns:
            # Convertir todos los valores a string, eliminar espacios en blanco y forzar minúsculas
            df[col] = df[col].astype(str).str.strip().str.lower()

            # Reemplazar cualquier variación de 's/i' con NaN y corregir separadores decimales
            df[col] = df[col].replace(r"[^0-9\.\,]", "", regex=True)  # Mantener solo números, punto y coma
            df[col] = df[col].replace({"s/i": np.nan, ",": "."}, regex=True)

            # Verificar si aún existen valores no convertibles antes de aplicar pd.to_numeric()
            invalid_values = df[~df[col].str.replace(r"[\d\.]", "", regex=True).eq("")]

            if not invalid_values.empty:
                print(f"⚠️ Advertencia: Se detectaron valores que no pueden convertirse a numérico en {col}.")
                print(invalid_values)

            # Convertir a float de manera segura
            df[col] = pd.to_numeric(df[col], errors="coerce")

            # Validación: Eliminar valores negativos reemplazándolos por NaN
            df[col] = df[col].apply(lambda x: x if (x >= 0 and x <= 1) else np.nan)

            # Mostrar advertencia si existen valores fuera de rango
            invalid_out_of_range = df[col].isna().sum()
            if invalid_out_of_range > 0:
                print(f"⚠️ Se detectaron {invalid_out_of_range} valores fuera del rango [0,1] en {col}. Fueron reemplazados por NaN.")

            # Verificar cuántos valores NaN quedaron tras la conversión
            print(f"Valores NaN en {col} después de la conversión: {df[col].isnull().sum()}")

            # Aplicar imputación de valores NaN
            if df[col].isnull().sum() > 0:
                df[col] = df.groupby(["id_carr_gen", "tipo_inst"])[col].transform(lambda x: x.fillna(x.mean()))
                df[col] = df.groupby("tipo_inst")[col].transform(lambda x: x.fillna(x.mean()))
                df[col] = df[col].fillna(df[col].mean())  # Imputación global si aún hay NaN

            # Verificar nuevamente los valores NaN después de la imputación
            print(f"Valores NaN en {col} después de la imputación: {df[col].isnull().sum()}")

    # Actualizar el dataset en el diccionario
    dataframes["ret"] = df

    print("✅ Proceso de conversión, validación de rango e imputación completado correctamente.")

else:
    print("❌ ERROR: El dataset 't_ret' no se encuentra en el diccionario.")
# Out:
# ⚠️ Se detectaron 31 valores fuera del rango [0,1] en tasa_ret_1er_anio. Fueron reemplazados por NaN.
# Valores NaN en tasa_ret_1er_anio después de la conversión: 31
# Valores NaN en tasa_ret_1er_anio después de la imputación: 0
# ⚠️ Se detectaron 741 valores fuera del rango [0,1] en tasa_ret_2do_anio. Fueron reemplazados por NaN.
# Valores NaN en tasa_ret_2do_anio después de la conversión: 741
# Valores NaN en tasa_ret_2do_anio después de la imputación: 0
# ✅ Proceso de conversión, validación de rango e imputación completado correctamente.

# %%
# Verificación
dataframes['ret']['tasa_ret_1er_anio'].describe()
# dataframes['ret']['tasa_ret_2do_anio'].describe()
# Out:
# count    1078.000000
# mean        0.698037
# std         0.078288
# min         0.389937
# 25%         0.647464
# 50%         0.700821
# 75%         0.751221
# max         0.955857
# Name: tasa_ret_1er_anio, dtype: float64

# %% [markdown]
# <blockquote>
#     <ul>
#         <li>Se reducen los valores nulos, mejorando la calidad de los datos.</li>
#         <li>Se reemplazan valores no numéricos para columnas que se usarán como variable objetivo.</li>
#         <li>Se utilizan expresiones regulares para reemplazar puntos por comas en valores numéricos decimales.</li>
#         <li>Se asegura que los modelos puedan procesar los datos sin errores.</li>
#     </ul>
# </blockquote>

# %% [markdown]
# 5. <b>Detección y eliminación de outliers.</b><br>
# <blockquote>
#     Se identifican valores atípicos usando el rango intercuartílico (IQR) y se eliminan los datos que están fuera de los límites.
# </blockquote>

# %%
for name, df in dataframes.items():
    for col in df.select_dtypes(include=['float64', 'int64']).columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

    dataframes[name] = df  # Guardar el dataframe actualizado

# %%
# Verificación
dataframes['ret']['tasa_ret_1er_anio'].describe()
# dataframes['ret']['tasa_ret_2do_anio'].describe()
# Out:
# count    727.000000
# mean       0.690826
# std        0.069496
# min        0.500000
# 25%        0.645687
# 50%        0.694840
# 75%        0.741396
# max        0.888889
# Name: tasa_ret_1er_anio, dtype: float64

# %% [markdown]
# <blockquote>
#     <ul>
#         <li>Se eliminan valores atípicos que podrían distorsionar el análisis.</li>
#         <li>Se mejora la estabilidad del modelo al trabajar con datos dentro de un rango razonable.</li>
#     </ul>
# </blockquote>

# %% [markdown]
# 6. <b>Codificación de variables categóricas.</b><br>
# <blockquote>
#     Las variables categóricas se convierten a valores numéricos mediante <i>Label Encoding</i>.
# </blockquote>

# %%
for name, df in dataframes.items():
    for col in df.select_dtypes(include=['object']).columns:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col])

    dataframes[name] = df  # Guardar el dataframe actualizado

# %% [markdown]
# <blockquote>
#     <ul>
#         <li>Se transforman los datos categóricos en un formato que los modelos de Machine Learning pueden entender.</li>
#         <li>Se mantiene la información original, asignando un número único a cada categoría.</li>
#     </ul>
# </blockquote>

# %% [markdown]
# 7. <b>Normalización y escalado de datos.</b><br>
# <blockquote>
#     Se aplica <i>MinMaxScaler</i> para estandarizar las variables numéricas y mejorar la estabilidad de los modelos.
# </blockquote>

# %%
scaler = MinMaxScaler(feature_range=(0, 1))  # Escala entre 0 y 1

for name, df in dataframes.items():
    if df.shape[0] > 0:  # Verificar que el DataFrame no esté vacío
        numeric_cols = df.select_dtypes(include=["float64", "int64"]).columns

        if len(numeric_cols) > 0:  # Verificar que haya columnas numéricas
            df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

        dataframes[name] = df  # Guardar el dataframe procesado
    else:
        print(f"⚠️ Advertencia: El dataset '{name}' está vacío después del preprocesamiento y no se ha escalado.")
# Out:
# ⚠️ Advertencia: El dataset 'pac_num' está vacío después del preprocesamiento y no se ha escalado.
# ⚠️ Advertencia: El dataset 'pac_jce' está vacío después del preprocesamiento y no se ha escalado.

# %%
# Verificación
dataframes['ret']['tasa_ret_1er_anio'].describe()
# dataframes['ret']['tasa_ret_2do_anio'].describe()
# Out:
# count    727.000000
# mean       0.490697
# std        0.178704
# min        0.000000
# 25%        0.374624
# 50%        0.501017
# 75%        0.620734
# max        1.000000
# Name: tasa_ret_1er_anio, dtype: float64

# %%
# Generación de archivo CSV con la data del dataframe 'ret' procesada
dataframes['ret'].to_csv('ret_procesado.csv', sep=';' ,index=False)

# %% [markdown]
# <blockquote>
#     <ul>
#         <li>Los datos numéricos tienen una distribución con media 0 y desviación estándar 1.</li>
#         <li>Se reduce la influencia de escalas distintas entre variables.</li>
#     </ul>
# </blockquote>

# %% [markdown]
# <i>Observaciones:</i>
# Los archivos <b>t_pac_jce_cft_ip_sies.csv</b> y <b>t_pac_num_cft_ip_sies.csv</b> tienen registros en su estado original, pero después del preprocesamiento quedan vacíos.
#
# <ul><u>Estado antes del preprocesamiento</u>:
#     <li>pac_jce: 644 filas y 44 columnas con 13,807 valores nulos.</li>
#     <li>pac_num: 644 filas y 48 columnas con 14,466 valores nulos.</li>
# </ul>
#
#
# <ul><u>Estado después del preprocesamiento</u>:
#     <li>Ambos datasets quedaron vacíos (0 filas) después de la imputación de valores nulos y la eliminación de outliers.</li>
# </ul>
#
# <ul><u>Causas posibles de la pérdida de datos</u>:
#     <li>Alto porcentaje de valores nulos: En algunos casos, la imputación de valores nulos no es suficiente y se eliminan filas completas.</li>
#     <li>Eliminación agresiva de outliers: Si la variabilidad de los datos es alta, se pueden haber eliminado la mayoría de los registros al aplicar el método IQR.</li>
# <ul>

# %% [markdown]
# <i>Observaciones de ajuste:</i>
#
# <ul>A pesar de haber modificado la estrategia de limpieza mediante:
#     <li>Imputación de valores numéricos con la media en lugar de la mediana.</li>
#     <li>Ajuste en la detección de outliers usando percentiles 10 y 90 en lugar de los cuartiles 25 y 75.</li>
#     <li>Los datasets siguen quedando sin registros.</li>
# </ul>

# %% [markdown]
# 8. <b>Generación de gráficos exploratorios.</b><br>
# <blockquote>
#     Se generan histogramas para visualizar la distribución de las variables numéricas.
# </blockquote>

# %%
for name, df in dataframes.items():
    df.select_dtypes(include=['float64', 'int64']).hist(bins=30, figsize=(12, 8))
    plt.suptitle(f"Distribución de Variables Numéricas - {name}", fontsize=14)
    plt.show()

# %% [markdown]
# <blockquote>
#     <ul>
#         <li>Se identifican patrones y sesgos en los datos.</li>
#         <li>Se observa la necesidad de posibles transformaciones adicionales.</li>
#     </ul>
# </blockquote>

# %% [markdown]
# <blockquote>
# 📌 <i><b>Conclusiones Generales</b></i>:
#     <ul>
#         <li>Se identificaron patrones clave en la distribución de variables numéricas.</li>
#         <li>Algunas variables tienen distribuciones sesgadas, lo que indica la necesidad de transformación antes del modelado.</li>
#         <li>Se detectaron outliers en algunas variables que podrían influir en los análisis predictivos.</li>
#         <li>Las tendencias observadas en matrícula, empleabilidad e ingresos pueden ayudar a diseñar estrategias de retención y mejora académica.</li>
#     </ul>
# </blockquote>

# %% [markdown]
# <b>B) Matriz de correlación entre variables numéricas</b>

# %% [markdown]
# <blockquote>
#     Se generó una matriz de correlación para evaluar la relación entre variables numéricas, permitiendo identificar cuáles tienen mayor impacto en la tasa de retención.
# </blockquote>

# %%
# Definir la variable objetivo
target_variable = "tasa_ret_1er_anio" 

# Generar matriz de correlación para cada dataset que contenga la variable
for name, df in dataframes.items():
    if target_variable in df.columns:  # Solo procesar si la variable está en el dataset
        
        # Convertir la variable objetivo a tipo numérico (forzar conversión)
        df[target_variable] = pd.to_numeric(df[target_variable], errors="coerce")

        # Seleccionar columnas numéricas
        numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

        if len(numeric_cols) > 1:  # Verificar que haya suficientes variables numéricas
            plt.figure(figsize=(10, 8))
            correlation_matrix = df[numeric_cols].corr()
            sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
            plt.title(f"Matriz de Correlación - {name}")
            plt.show()

            # Mostrar las variables más correlacionadas con la tasa de retención
            correlated_features = correlation_matrix[target_variable].sort_values(ascending=False)
            print(f"\nVariables más correlacionadas con la tasa de retención en {name}:")
            print(correlated_features)
# Out:
# Variables más correlacionadas con la tasa de retención en ret:
# tasa_ret_1er_anio    1.000000
# tasa_ret_2do_anio    0.127304
# id_carr_gen          0.115262
# coho_mat             0.104614
# Name: tasa_ret_1er_anio, dtype: float64

# %% [markdown]
# <b>C) Análisis de relación entre variables numéricas y la retención.</b>

# %% [markdown]
# <blockquote>
#     Se generaron gráficos de dispersión para visualizar cómo varía la tasa de retención en función de otras variables clave.
# </blockquote>

# %%
# Crear gráficos de dispersión para analizar relaciones entre variables numéricas y las tasas de retención
fig, axes = plt.subplots(2, 2, figsize=(14, 12))

# Extraer el dataset 'ret' del diccionario de dataframes
df_ret = dataframes["ret"]

# Relación entre tasa_ret_1er_anio y tasa_ret_2do_anio
sns.scatterplot(x=df_ret["tasa_ret_1er_anio"], 
                y=df_ret["tasa_ret_2do_anio"], ax=axes[0, 0])
axes[0, 0].set_title("Relación entre tasa_ret_1er_anio y tasa_ret_2do_anio")
axes[0, 0].set_xlabel("Tasa Retención 1er Año")
axes[0, 0].set_ylabel("Tasa Retención 2do Año")

# Relación entre id_carr_gen y tasa_ret_1er_anio
sns.scatterplot(x=df_ret["id_carr_gen"], 
                y=df_ret["tasa_ret_1er_anio"], ax=axes[0, 1])
axes[0, 1].set_title("Relación entre id_carr_gen y tasa_ret_1er_anio")
axes[0, 1].set_xlabel("ID Carrera Genérica")
axes[0, 1].set_ylabel("Tasa Retención 1er Año")

# Relación entre cohorte de matrícula (coho_mat) y tasa_ret_1er_anio
sns.scatterplot(x=df_ret["coho_mat"], 
                y=df_ret["tasa_ret_1er_anio"], ax=axes[1, 0])
axes[1, 0].set_title("Relación entre coho_mat y tasa_ret_1er_anio")
axes[1, 0].set_xlabel("Cohorte de Matrícula")
axes[1, 0].set_ylabel("Tasa Retención 1er Año")

# Relación entre cohorte de matrícula (coho_mat) y tasa_ret_2do_anio
sns.scatterplot(x=df_ret["coho_mat"], 
                y=df_ret["tasa_ret_2do_anio"], ax=axes[1, 1])
axes[1, 1].set_title("Relación entre coho_mat y tasa_ret_2do_anio")
axes[1, 1].set_xlabel("Cohorte de Matrícula")
axes[1, 1].set_ylabel("Tasa Retención 2do Año")

# Ajustar distribución de los gráficos
plt.tight_layout()

# Mostrar gráficos
plt.show()

# %% [markdown]
# 1️⃣ **Relación entre tasa de retención en primer año y tasa de retención en segundo año**
# * Se observa una dispersión notable en la relación entre ambas tasas, lo que sugiere que no existe una dependencia lineal clara entre la retención del primer año y la del segundo.
#
# * Hay una concentración significativa de puntos a lo largo de una línea horizontal en ciertos valores de retención, lo que indica que muchos programas tienen una estabilidad relativa en la retención del segundo año, independientemente del comportamiento del primero.
#
# * La variabilidad de la retención en el segundo año puede estar influenciada por factores adicionales que no están capturados directamente en la retención del primer año.
#
# 2️⃣ **Relación entre ID de la carrera genérica y tasa de retención en primer año**
# * Los puntos están ampliamente distribuidos en todo el eje horizontal, lo que indica que la retención en el primer año no depende exclusivamente del identificador de la carrera.
#
# * No se observan patrones evidentes de agrupamiento en carreras específicas, lo que sugiere que la retención no es homogénea en función del tipo de programa académico.
#
# * La dispersión de los valores refuerza la necesidad de considerar otros atributos (como el área de conocimiento, la acreditación institucional o factores socioeconómicos) para entender mejor los determinantes de la retención.
#
# 3️⃣ **Relación entre cohorte de matrícula y tasa de retención en primer año**
# * Se identifican patrones en la disposición vertical de los puntos, lo que sugiere que la retención varía dependiendo del tamaño y la composición de la cohorte de matrícula.
#
# * Existen ciertos valores de cohorte donde la retención es significativamente más alta o más baja en comparación con otros, lo que puede estar relacionado con cambios en políticas institucionales, la oferta académica o la composición del estudiantado en distintos años.
#
# * La regularidad en la disposición de los puntos puede reflejar prácticas institucionales estandarizadas en cuanto a retención.
#
# 4️⃣ **Relación entre cohorte de matrícula y tasa de retención en segundo año**
# * Al igual que en el gráfico anterior, se observan ciertos patrones de distribución vertical, lo que sugiere que la retención en segundo año también está influenciada por el tamaño de la cohorte.
#
# * Se pueden identificar grupos de programas con tasas de retención más altas y más bajas dentro de los mismos rangos de cohorte, lo que indica que la permanencia en el segundo año podría estar condicionada por factores institucionales y académicos más específicos.

# %% [markdown]
# <b>D) Análisis de variables categóricas.</b>

# %% [markdown]
# <blockquote>
#     Se evalúa cómo las variables categóricas (tipo de institución, área de estudio, región) influyen en la retención mediante gráficos de caja.
# </blockquote>

# %%
# Análisis de relación entre variables categóricas y la retención
categorical_vars = ["tipo_inst", "area_carr", "región_sede"]  # Ajustar según el dataset

for name, df in dataframes.items():
    for cat_var in categorical_vars:
        if cat_var in df.columns and target_variable in df.columns:
            plt.figure(figsize=(12, 6))
            sns.boxplot(x=df[cat_var], y=df[target_variable])
            plt.xticks(rotation=45)
            plt.title(f"Distribución de Tasa de Retención por {cat_var} - {name}")
            plt.xlabel(cat_var)
            plt.ylabel("Tasa de Retención")
            plt.show()

# %% [markdown]
# 1️⃣ **Distribución de la Tasa de Retención por Área de Carrera**
# * Se observa que la tasa de retención varía significativamente entre las diferentes áreas de estudio.
# * Algunas áreas presentan una mediana de retención más alta, lo que sugiere que los estudiantes que ingresan a esas carreras tienen una mayor probabilidad de continuar sus estudios.
# * La dispersión en algunas áreas es considerable, con presencia de valores atípicos, lo que sugiere una alta variabilidad en la retención dentro de ciertas carreras.
# * Se identifican áreas con valores atípicos en la parte baja, lo que indica carreras donde un grupo reducido de estudiantes presenta una retención significativamente menor.
#
# 📌 _Hallazgos clave_:
# * Existen áreas que presentan una retención más estable con menos dispersión, lo que podría estar relacionado con factores como la oferta académica, el nivel de exigencia o la vocación de los estudiantes.
# * Otras áreas presentan mayor dispersión y presencia de valores extremos, lo que podría estar asociado a carreras con alta deserción o factores institucionales.
#
# 2️⃣ **Distribución de la Tasa de Retención por Tipo de Institución**
# * La retención en los distintos tipos de instituciones muestra una distribución similar, aunque con diferencias sutiles en la mediana y el rango intercuartílico.
# * Algunas instituciones presentan mayor variabilidad, con una dispersión más amplia en la tasa de retención.
# * Se observa la presencia de valores atípicos en algunas instituciones, lo que sugiere que en ciertos casos la retención es significativamente más baja en comparación con el promedio general.
#
# 📌 _Hallazgos clave_:
# * Aunque la retención es relativamente homogénea entre los diferentes tipos de instituciones, algunas parecen tener estudiantes con tasas de retención más altas.
# * La existencia de valores atípicos sugiere que en ciertas instituciones hay carreras o programas con menor retención, lo que podría estar influenciado por la oferta académica, el nivel de preparación de los estudiantes o factores administrativos.

# %% [markdown]
# <b>E) Selección final de atributos para el modelo.</b>

# %% [markdown]
# Basado en el análisis exploratorio de datos, se seleccionaron las siguientes variables para alimentar el modelo:
#
# 📌 **Variables Objetivo (Target)**
# * **<code>tasa_ret_1er_anio</code>** (Tasa de retención en primer año)
# * **<code>tasa_ret_2do_anio</code>** (Tasa de retención en segundo año)
#
# 📌 **Variables Predictoras (Features)**
# * **<code>id_carr_gen</code>** → Código de carrera genérica (posible impacto en la retención según correlación)
# * **<code>coho_mat</code>** → Cohorte de matrícula (podría influir en la retención según dispersión)
# * **<code>area_carr</code>** → Área de la carrera (diferencias en retención observadas en los boxplots)
# * **<code>tipo_inst</code>** → Tipo de institución (posible factor diferenciador según retención)

# %%
# Copiar el dataset "ret" del diccionario para no modificar el original
df = dataframes["ret"].copy()

# 📌 1️⃣ Variables seleccionadas según análisis
target_columns = ["tasa_ret_1er_anio", "tasa_ret_2do_anio"]
numerical_features = ["id_carr_gen", "coho_mat"]
categorical_features = ["area_carr", "tipo_inst"]

# 📌 2️⃣ Validación de valores negativos en tasas de retención
for col in target_columns:
    df = df[df[col] >= 0]  # Filtra valores negativos

# 📌 3️⃣ Normalización de Variables Numéricas
scaler = StandardScaler()
df[numerical_features] = scaler.fit_transform(df[numerical_features])

# 📌 4️⃣ Codificación de Variables Categóricas
encoder = OneHotEncoder(drop="first", sparse_output=False)  # Evita colinealidad
encoded_cats = encoder.fit_transform(df[categorical_features])
encoded_cats_df = pd.DataFrame(
    encoded_cats,
    columns=encoder.get_feature_names_out(categorical_features),
    index=df.index,
)

# 📌 5️⃣ Concatenar todas las variables preparadas
df_final = pd.concat([df[target_columns], df[numerical_features], encoded_cats_df], axis=1)

# 📌 6️⃣ Guardar el dataset procesado en el diccionario
dataframes["ret_processed"] = df_final

print("✅ Transformación de atributos completada correctamente.")
# Out:
# ✅ Transformación de atributos completada correctamente.

# %% [markdown]
# <b>F) Desarrollo del Modelo de Machine Learning.</b>

# %% [markdown]
# En este proceso, se desarrolló un modelo de Machine Learning utilizando Regresión Lineal para predecir la retención de estudiantes en Instituciones de Educación Técnico-Profesional en Chile (CFT e IP). A continuación, se explica detalladamente cada paso, desde la carga de datos hasta la evaluación del modelo, para comprender qué significa cada métrica obtenida y cómo se podrían mejorar los resultados.

# %% [markdown]
# <blockquote>
#     📌 Paso 1: Cargar el dataset preprocesado y verificar la estructura.
# </blockquote>

# %% [markdown]
# * Antes de entrenar cualquier modelo, es fundamental asegurarse de que los datos han sido correctamente procesados y están listos para su uso.
# * Si los datos contienen valores nulos, errores o si alguna variable importante falta, el modelo no podrá entrenarse correctamente o arrojará resultados erróneos.

# %%
# Cargar el dataset procesado desde el diccionario
if "ret_processed" in dataframes:
    df_model = dataframes["ret_processed"].copy()
    print("✅ Dataset 'ret_processed' cargado correctamente.")
else:
    raise ValueError("❌ ERROR: El dataset 'ret_processed' no está en el diccionario. Verifica el preprocesamiento.")
    
# Validar estructura del dataframe
if df_model.empty:
    raise ValueError("❌ ERROR: El dataset está vacío después del preprocesamiento.")
else:
    print(f"📊 Dimensiones del dataset: {df_model.shape}")
    print(f"📋 Columnas disponibles: {df_model.columns.tolist()}")
# Out:
# ✅ Dataset 'ret_processed' cargado correctamente.
# 📊 Dimensiones del dataset: (727, 16)
# 📋 Columnas disponibles: ['tasa_ret_1er_anio', 'tasa_ret_2do_anio', 'id_carr_gen', 'coho_mat', 'area_carr_1', 'area_carr_2', 'area_carr_3', 'area_carr_4', 'area_carr_5', 'area_carr_6', 'area_carr_7', 'area_carr_8', 'area_carr_9', 'tipo_inst_1', 'tipo_inst_2', 'tipo_inst_3']

# %% [markdown]
# <blockquote>
#     📌 Paso 2: Definir variables objetivo y predictoras
# </blockquote>

# %% [markdown]
# En este paso, se seleccionaron las variables que se utilizarán en el modelo de Machine Learning. La correcta elección de variables es fundamental para mejorar la precisión del modelo y evitar ruido innecesario.
#
# * **Variables Objetivo (Target)**: Son aquellas que quieren predecir. En este caso, interesa conocer la tasa de retención de los estudiantes en el primer año y en el segundo año.
# * **Variables Predictoras (Features)**: Son los factores que pueden influir en la retención. Estas variables se usarán para entrenar el modelo y buscar patrones.

# %%
# Definir variables
target_columns = ["tasa_ret_1er_anio", "tasa_ret_2do_anio"]
features = [col for col in df_model.columns if col not in target_columns]

# Verificar si las variables existen en el dataframe
missing_cols = [col for col in target_columns if col not in df_model.columns]
if missing_cols:
    raise ValueError(f"❌ ERROR: Las siguientes variables objetivo no se encuentran en el dataset: {missing_cols}")
else:
    print("✅ Variables objetivo encontradas correctamente.")

# Separar X (features) e Y (targets)
X = df_model[features]
Y = df_model[target_columns]

print(f"📊 Variables predictoras seleccionadas: {len(features)}")
# Out:
# ✅ Variables objetivo encontradas correctamente.
# 📊 Variables predictoras seleccionadas: 14

# %% [markdown]
# <blockquote>
#     📌 Paso 3: División del Dataset en Conjunto de Entrenamiento y Prueba
# </blockquote>

# %% [markdown]
# El dataset fue dividido en dos partes:
#
# * 80% para entrenamiento (X_train, Y_train)
# * 20% para prueba (X_test, Y_test)
#
# Observaciones:
#
# * Se divide el dataset para asegurarse que el modelo pueda hacer predicciones sobre datos nuevos que nunca ha visto antes. Esto ayuda a medir su capacidad de generalización.
#
# * Si no se divide el dataset, el modelo memorizaría los datos en lugar de aprender patrones generales, lo que provocaría un sobreajuste y una baja precisión en datos nuevos.

# %%
# División en 80% entrenamiento y 20% prueba
try:
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
    print(f"✅ División de datos completada con éxito.")
    print(f"📊 Conjunto de Entrenamiento: {X_train.shape[0]} registros")
    print(f"📊 Conjunto de Prueba: {X_test.shape[0]} registros")
except Exception as e:
    raise ValueError(f"❌ ERROR en la división de datos: {e}")
# Out:
# ✅ División de datos completada con éxito.
# 📊 Conjunto de Entrenamiento: 581 registros
# 📊 Conjunto de Prueba: 146 registros

# %% [markdown]
# <blockquote>
#     📌 Paso 4: Entrenamiento del modelo de Machine Learning
# </blockquote>

# %% [markdown]
# Para entrenar el modelo se utilizó Regresión Lineal, que es un algoritmo que busca la mejor relación matemática entre las variables predictoras y la variable objetivo. De acuerdo a esto:
# * Es fácil de interpretar y visualizar.
# * Permite entender qué factores tienen más peso en la retención.
# * Sirve como modelo base para comparar con otros modelos más complejos como:
#     - Random Forest: Captura relaciones no lineales y ofrece mejores predicciones.
#     - XGBoost: Más potente para detectar patrones complejos en los datos.
#     - Redes Neuronales: Recomendadas si el dataset tuviera una cantidad mucho mayor de datos.
#
# Sin embargo, para este caso inicial, la Regresión Lineal permitió establecer una base y evaluar la viabilidad del modelo.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.exceptions import NotFittedError

# Inicializar el modelo
modelo = LinearRegression()

# Entrenar el modelo y verificar que se haya completado correctamente
try:
    modelo.fit(X_train, Y_train)
    print("✅ Modelo entrenado correctamente.")
except Exception as e:
    raise ValueError(f"❌ ERROR en el entrenamiento del modelo: {e}")
# Out:
# ✅ Modelo entrenado correctamente.

# %% [markdown]
# <blockquote>
#     📌 Paso 5: Predicción y evaluación del modelo
# </blockquote>

# %% [markdown]
# Después de entrenar el modelo, se realizan predicciones sobre el conjunto de prueba (X_test) y comparan los valores predichos con los valores reales (Y_test).

# %%
# Intentar hacer predicciones
try:
    Y_pred = modelo.predict(X_test)
except NotFittedError:
    raise ValueError("❌ ERROR: El modelo no ha sido entrenado correctamente.")
except Exception as e:
    raise ValueError(f"❌ ERROR al hacer predicciones: {e}")

# Evaluación de métricas
mae = mean_absolute_error(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print(f"📊 Evaluación del Modelo:")
print(f"🔹 MAE (Error Absoluto Medio): {mae:.4f}")
print(f"🔹 MSE (Error Cuadrático Medio): {mse:.4f}")
print(f"🔹 R² Score (Coeficiente de Determinación): {r2:.4f}")
# Out:
# 📊 Evaluación del Modelo:
# 🔹 MAE (Error Absoluto Medio): 0.0931
# 🔹 MSE (Error Cuadrático Medio): 0.0176
# 🔹 R² Score (Coeficiente de Determinación): 0.2170

# %% [markdown]
# ##### 3.3.4 Resultados.

# %% [markdown]
# **MAE = 0.0931**
# * Descripción: El MAE mide el error promedio absoluto entre las predicciones del modelo y los valores reales.
# * Resultados: En este caso, en promedio, la predicción del modelo se equivoca en 0.0931 unidades de retención.
# * Valores ideales: Un MAE cercano a 0 indica un modelo más preciso.
#
# **MSE = 0.0176**
# * Descripción: El MSE calcula el error cuadrático medio, penalizando los errores grandes.
# * Resultados: Este valor indica que, en promedio, el error al predecir la tasa de retención es de 0.0176 unidades.
# * Valores ideales: Cuanto más cercano a 0, mejor será el modelo.
#
# **R² Score = 0.2170**
# * Descripción: El R² Score mide qué porcentaje de la variabilidad en la tasa de retención es explicada por el modelo.
# * Resultados: En este caso, un R² de 0.2170 significa que el modelo solo explica el 21.7% de la variabilidad en la retención. Esto indica que hay otros factores no considerados en los datos que podrían influir en la retención.
# * Rango de valores:
#     * Si R² es 1, significa que el modelo explica toda la variabilidad.
#     * Si R² es 0, significa que el modelo no explica nada de la variabilidad.

# %% [markdown]
# ### <b>4. CONCLUSIONES</b>

# %% [markdown]
# El presente estudio ha permitido analizar y modelar la retención de estudiantes en Instituciones de Educación Superior Técnico-Profesional en Chile, utilizando técnicas de Machine Learning. A través de un proceso estructurado de análisis exploratorio, selección de atributos y evaluación del modelo, se han obtenido hallazgos relevantes sobre los factores que inciden en la continuidad de los estudiantes en sus programas académicos.
#
# **1. Factores que influyen en la retención de estudiantes**
# El análisis ha demostrado que la retención estudiantil está determinada por diversos factores tanto académicos como institucionales:
# * **Área de la carrera:** Se ha observado que ciertas áreas de estudio presentan tasas de retención más altas que otras, lo que sugiere que el nivel de dificultad y las oportunidades laborales pueden ser factores determinantes.
# * **Tipo de institución:** Existen diferencias en las tasas de retención entre Institutos Profesionales (IP) y Centros de Formación Técnica (CFT), posiblemente debido a diferencias en la estructura curricular, la empleabilidad o la oferta de financiamiento.
# * **Tamaño de la cohorte de matrícula:** Cohortes más grandes pueden representar desafíos en términos de disponibilidad de recursos, atención personalizada y calidad en la enseñanza, impactando la retención de los estudiantes.
# * **Código de carrera genérica:** La variabilidad en la retención entre diferentes programas académicos sugiere que la naturaleza de cada carrera puede influir en la decisión de los estudiantes de continuar o abandonar sus estudios.
#
# **2. Predecir con anticipación qué estudiantes tienen mayor riesgo de abandonar**
# La evaluación del modelo ha mostrado que, si bien es posible realizar predicciones sobre la retención de estudiantes, los resultados presentan ciertas limitaciones:
# * **Error Absoluto Medio (MAE) de 0.0931:** Indica que, en promedio, las predicciones del modelo tienen una desviación de aproximadamente 9.3% con respecto a los valores reales.
# * **Error Cuadrático Medio (MSE) de 0.0176:** Refleja que el modelo tiene cierta capacidad de ajuste, pero aún con margen de mejora.
# * **Coeficiente de Determinación (R²) de 0.2170:** Sugiere que las variables utilizadas explican aproximadamente un 21.7% de la variabilidad en la retención, lo que indica que hay otros factores no contemplados en el modelo que podrían mejorar la precisión.
# Si bien el modelo permite identificar tendencias generales en la retención estudiantil, la capacidad predictiva es limitada. Esto sugiere que la retención está influenciada por factores adicionales no considerados en el análisis, como condiciones socioeconómicas, desempeño académico individual, satisfacción estudiantil y factores personales.

# %% [markdown]
# ### 5. Recomendaciones y Perspectiva.

# %% [markdown]
# Los hallazgos de este estudio resaltan la importancia de diseñar estrategias institucionales proactivas para mejorar la retención estudiantil.
#
# Algunas recomendaciones incluyen:
# * **Monitoreo Temprano:** Implementar sistemas de alerta temprana que identifiquen estudiantes en riesgo de deserción, basados en patrones históricos de retención.
# * **Apoyo Académico:** Fortalecer programas de nivelación, tutorías y acompañamiento académico para estudiantes de primer año, especialmente en carreras con baja retención.
# * **Flexibilidad Curricular:** Evaluar la posibilidad de flexibilizar la malla curricular, permitiendo adaptaciones según las necesidades de los estudiantes.
# * **Becas y Financiamiento:** Diseñar programas de apoyo financiero para estudiantes con dificultades económicas, dado que este factor puede ser determinante en la continuidad académica.
# * **Fortalecimiento del Vínculo Institucional:** Promover actividades de integración, orientación vocacional y acompañamiento psicoeducativo para mejorar la experiencia estudiantil y su sentido de pertenencia.
# * **Mejoramiento de la Calidad Docente:** Capacitar continuamente a los docentes para mejorar las metodologías de enseñanza y la interacción con los estudiantes.
#
# El desarrollo de modelos predictivos para la retención estudiantil representa un avance significativo en la gestión de la educación superior técnico-profesional en Chile. Sin embargo, la retención es un fenómeno multifactorial que requiere un enfoque integral, combinando el análisis de datos con estrategias de apoyo institucional.
#
# La implementación de nuevas e innovadoras herramientas de gestión podría contribuir a la mejora continua del proceso educativo, permitiendo que las instituciones puedan anticiparse a los problemas de deserción y aplicar estrategias más efectivas para mejorar la retención estudiantil.
#
# Este estudio abre la puerta a futuras investigaciones que integren nuevas variables, mejores modelos de predicción y el uso de tecnologías avanzadas como la inteligencia artificial para una gestión más eficiente y personalizada del éxito académico.

# %% [markdown]
# ### 6. Referencia Bibliográfica.

# %% [markdown]
# * Agudo, F. & Olcese, A. (2019). Modulo Infraestructura Big Data. CEUPE.
# * Cañones, D & Santos, J (2019). Lenguajes de Programacion. CEUPE
# * Cañones, D & Santos, J (2019). Estudio y Modelado del Dato . CEUPE
# * Cañones, D & Santos, J (2019). Herramientas y Librerias . CEUPE
# * Noever, D. The Enron Corpus: Where the Email Bodies are Buried? Hunstville, USA.
# * Malone, K & Thrun,S. Introduction to Machine Learning. Udacity. Sitio Web: https://www.udacity.com/course/intro-to-machine-learning--ud120
# * Cukierski, W (2016). The Enron Email Dataset, Kaggle Sitio Web: https://www.kaggle.com/* wcukierski/enron-email-dataset/tasks?taskId=1013
# * Khandelwal, R (2020) A Quick and Easy Guide to Managing Conda Environments. Sitio Web: https://towardsdatascience.com/a-quick-and-easy-guide-to-managing-conda-environments-87bfe7bab065
# * Python Software Foundation (2023), Python 3.12.4 documentation. Sitio Web: https://docs.python.org/release/3.12.4

# %% [markdown]
# ### 7. Anexos.

# %% [markdown]
# Histogramas y descripciones mostrados más arriba.
